# %% [markdown]
# <a href="https://colab.research.google.com/github/DIFACQUIM/Cursos/blob/main/8_1_Reacciones_qu%C3%ADmicas__Enumeraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Enumeración de bibliotecas químicas**

# %% [markdown]
# # Objetivos:
#
# ---
# * Ejemplificar el uso de la paquetería `SmilesDrawer` para la representación de reacciones químicas.
# * Adquirir competencias en el empleo de SMARTS y SMIRKS para codificar reacciones químicas.
# * Ilustrar la enumeración de bibliotecas químicas virtuales mediante un enfoque basado en reacciones químicas.

# %% [markdown]
# #Introducción:
#
# ---
#
# Dentro de los enfoques basados en reglas para el diseño de bibliotecas químicas, el diseño basado en esquemas de síntesis y reactivos disponibles han demostrado la importancia del conocimiento de reacciones inteligentes en el campo de la exploración del espacio químico. Integrar este conocimiento ha permitido diseñar bibliotecas sintéticamente accesibles, como BI-CLAIM  desarrollada por Boehringer Ingelheim (Lessel et al, 2009) y CHIPMUNK (Humbeck et al., 2018). Otro ejemplo es la biblioteca TIN, una base de datos de química combinatoria construida alrededor de la viabilidad sintética de reacciones multicomponente que contiene más de 28 millones de estructuras de productos que son novedosos y sintéticamente accesibles (Dorschner et al., 2011). De manera similar, y tomando en cuenta las reacciones de química click de los triazoles, se generó la base de datos ZINClick que está compuesta por más de 16 millones de 1,2,3- y 1,4-triazoles disustituidos, cuyas estructuras son novedosas y sintéticamente factibles (Massarotti et al., 2014). Otra biblioteca virtual de acceso libre es 'Screenable Chemical Universe Based on Intuitive Data OrganizatiOn' (SCUBIDOO) (Chevillard & Kolb, 2015). En SCUBIDOO, se aplicaron 58 reacciones sólidas a 18 561 bloques de construcción moleculares comunes para generar más de 21 millones de compuestos. Otra biblioteca virtual es la base de datos REAL, descrita en la plataforma VirtualFlow que contiene más de 1.400 millones de compuestos de fabricación bajo demanda.
#
# Aunque cada biblioteca tiene sus variaciones, se pueden distinguir pasos en común que consisten en:
# 1. Seleccionar un enfoque de síntesis a seguir  y las reacciones a emplear (p. ej. síntesis orientada en biología (BIOS, del inglés biology-oriented synthesis), síntesis orientada en diversidad (DOS, del inglés diversity oriented synthesis), química combinatoria o síntesis tradicional).
# 2. Construir o identificar los bloques de construcción a emplear (generalmente bloques disponibles comercialmente).
# 3. Identificar las características de los bloques de construcción para la estrategia a seguir. En este paso se pueden filtrar los fragmentos de acuerdo a grupos funcionales o por precio.
# 4. Establecer las reacciones a utilizar en un formato legible para la computadora (por ejemplo, SMIRKS).
# 5. Uso de herramientas de quimioinformática para la automatización del enfoque de síntesis (p. ej. KNIME, RDKit o DataWarrior).
# 6. Implementación de filtros para la exclusión y remoción de compuestos duplicados o compuestos con alertas estructurales.
#
# A continuación describiremos ejemplos para representar reacciones químicas y enumerar una biblioteca química usando un enfoque basado en reacciones químicas.

# %% [markdown]
# #Ejercicios:
# ---

# %% [markdown]
# ### Representación de reacciones usando SMILES

# %% [markdown]
# 1. Instalar el faerun. Ver documentación

# %%
# !pip install faerun-notebook==0.1.5b0
# Out:
# Collecting faerun-notebook==0.1.5b0
#   Downloading faerun_notebook-0.1.5b0.tar.gz (534 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.0/535.0 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ipywidgets>=7.6.0 in /usr/local/lib/python3.11/dist-packages (from faerun-notebook==0.1.5b0) (7.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from faerun-notebook==0.1.5b0) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from faerun-notebook==0.1.5b0) (3.10.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->faerun-notebook==0.1.5b0) (2.8.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (75.1.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jedi/
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->faerun-notebook==0.1.5b0) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (5.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.1.5)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (0.23.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->faerun-notebook==0.1.5b0) (1.3.1)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Building wheels for collected packages: faerun-notebook
#   Building wheel for faerun-notebook (pyproject.toml) ... done
#   Created wheel for faerun-notebook: filename=faerun_notebook-0.1.5b0-py2.py3-none-any.whl size=470208 sha256=fd36b484840f81dc61144473142edf3806d83aee279a86852a2b4dbaa0c90e82
#   Stored in directory: /root/.cache/pip/wheels/d7/62/68/a4047bcd112e913e0e3d0095edc67419d1d75aa56e1703ef9c
# Successfully built faerun-notebook
# Installing collected packages: jedi, faerun-notebook
# Successfully installed faerun-notebook-0.1.5b0 jedi-0.19.2

# %% [markdown]
# 2. Importar las siguientes funciones:

# %%
import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# 3. Con la herramienta SmilesDrawer, colocar en las primeras comillas el título, en las segundas los dos reactivos separados por un punto y finalmente, separado entre ">>" está el producto de la reacción.
# Adicionalmente se colocó un tema, fondo y tamaño de la representación.
#
# Nota: SmilesDrawer es un componente capaz de analizar y dibujar estructuras moleculares codificadas con SMILES. Puede dibujar estructuras con estereoquímicas complejas sin usar plantilla y aún así tiene una huella computacional muy baja. Además tiene bajo uso de memoria sin necesidad de cargar imágenes. Estas caracteristicas permiten la representación de miles de dibujos de estructuras moleculares en una sóla página web

# %%
SmilesDrawer(value=[
    ("Condensación aldolica", "C1=CC=C(C=C1)C=O.CC(=O)C>>C1=CC=C(C=C1)C=CC(=O)C=CC2=CC=CC=C2")], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Condensación aldolica', 'C1…

# %% [markdown]
# Para unir elementos, únicamente se colocan en el corchete separados por comas y dentro de un paréntesis

# %%
SmilesDrawer(value=[
    ("Condensación aldolica", "C1=CC=C(C=C1)C=O.CC(=O)C>>C1=CC=C(C=C1)C=CC(=O)C=CC2=CC=CC=C2"),
    ("Ácido tereftálico", "C1=CC(=CC=C1C(=O)O)C(=O)O"),
    ("Una molécula", "CNCNCCN")
], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Condensación aldolica', 'C1…

# %% [markdown]
# Además del tema, se pueden cambiar distintos elementos gráficos como el grosor de las lineas

# %%
SmilesDrawer(value="C1=CC=C(C=C1)C=O.CC(=O)C>>C1=CC=C(C=C1)C=CC(=O)C=CC2=CC=CC=C2", theme='matrix', background="#000000", options={'scale': 1.5, 'bondThickness': 2.5})
# Out:
# SmilesDrawer(background='#000000', options={'scale': 1.5, 'bondThickness': 2.5}, theme='matrix', value='C1=CC=…

# %% [markdown]
# ### Enumeración de compuestos usando RDKit

# %% [markdown]
# Diseño de una bibioteca de compuestos bis-heterociclos obtenidos mediante química click utilizando la paquetería `RDKit`.
#
# 1. **Selección del enfoque de síntesis.**
# Este ejemplo se basa en el enfoque de síntesis reportado por Shafi et al. para obtener compuestos bis -heterociclos, vinculando bloques de construcción de heterociclos de 5 miembros que contienen uno o dos heteroátomos (al menos un nitrógeno, azufre, oxígeno) a un conjunto de bloques de construcción que contienen azida a través de la formación de un disustituido en 1,4 ,2,3-triazol mediante química click (Shafi et al., 2012).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. **Construcción o identificación de bloques de construcción.** Los bloques de construcción utilizados para este ejemplo se tomaron del catálogo de Sigma Aldrich (*Building Blocks*) presente en ZINC DB. Este catálogo consta de 124 368 bloques de construcción.
# Se eliminaron los compuestos duplicados y se seleccionaron los bloques de construcción que cumplen con la 'regla de tres' de Congreve (Crongreve et al., 2003). La base de datos seleccionada se puede encontrar como "Sigma_bb.sdf".
#
# NOTA: Para consultar otros catálogos de bloques de construcción disponibles comercialmente en ZINC puede acceder al siguiente enlace: https://zinc.docking.org/catalogs/

# %% [markdown]
# 3. **Identificar las características de los bloques de construcción para la estrategia a seguir.**
# Se construyeron los SMARTS para detectar la presencia de grupos funcionales apropiados para llevar a cabo el enfoque descrito en el punto 1.
#
# A continuación se describen las características para la construcción de cada SMARTS. Recuerde que para visualizar y editar los SMARTS utilizando  MarvinSketch o SMARTSPlus.
#
# * Anillo heterocíclico de 5 miembros con uno (N, O o S) o dos heteroátomos (N, O, S; al menos un N) y un sustituyente nucleofílico (- OH, –SH, –NH2 ).
#
# ![image.png](data:image/png;base64,...)
#
# * Alquino terminal 3-bromo o cloro sustituido.
#
# ![image.png](data:image/png;base64,...)
# * Azida.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. **Establecer las reacciones de emparejamiento en un formato legible SMIRKS.**

# %% [markdown]
# ![Gitbook (28).png](data:image/png;base64,...)

# %% [markdown]
# 5. **Uso de herramientas de quimioinformática para la automatización del enfoque de síntesis.**
# En este ejemplo utilizaremos la paquetería `RDKit` para generar la biblioteca de compuestos bis-heterociclos.  Ejemplos para la construcción  de bibliotecas químicas utilizando otras herramientas quimioinformáticas como KNIME y DataWarrior pueden consultarse en [Saldivar-González et al. 2020](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-020-00466-z).

# %% [markdown]
# a) Instale paqueterías y módulos a ocupar.

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.9.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.1.0)
# Downloading rdkit-2024.9.5-cp311-cp311-manylinux_2_28_x86_64.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 47.1 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.9.5

# %%
import pandas as pd
import rdkit as rk
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.rdMolDescriptors import CalcNumHeteroatoms
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem import rdMolDescriptors

# %% [markdown]
# b) Leer la biblioteca de bloques de construcción de Sigma usando la función `Supplier` de RDKit.

# %%
supp = Chem.SDMolSupplier('/content/Sigma_bb.sdf')
for mol in supp:
    if mol is not None: mol.GetNumAtoms()
# Out:
# [15:55:33] atom 2 has specified valence (2) smaller than the drawn valence 3.

# %% [markdown]
# c) Crear una lista que contenga los bloques de construcción de Sigma.

# %%
mols = [x for x in supp]
len(mols) #Numero de bloques de construcción
# Out:
# [15:55:38] atom 2 has specified valence (2) smaller than the drawn valence 3.
# 28355

# %% [markdown]
# d) Filtrar bloques de construcción de acuerdo a los SMARTS establecidos en el punto 3.

# %%
#SMARTS Anillo heterocíclico de 5 miembros
patt1= Chem.MolFromSmarts('[$([NX3;H2;!$(NC=O)]),$([#16X2H]),$([OX2H])]-[cr5;$([cr5]:1:[nr5,or5,sr5]:[cr5]:[cr5]:[nr5,or5,sr5]:1),$([cr5]:1:[cr5]:[nr5,or5,sr5]:[cr5]:[cr5]:1)]')
het5 = [x for x in mols if x.HasSubstructMatch(patt1)]
from rdkit.Chem import Draw
Draw.MolsToGridImage(list(het5), subImgSize=(300,300))
# Out:
# /usr/local/lib/python3.11/dist-packages/rdkit/Chem/Draw/IPythonConsole.py:343: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   warnings.warn(

# %%
##SMARTS Alquino terminal 3-bromo o cloro sustituido.
patt2= Chem.MolFromSmarts('[Br,Cl][#6]C#[CH1]')
alkynes = [x for x in mols if x.HasSubstructMatch(patt2)]
Draw.MolsToGridImage(list(alkynes), subImgSize=(300,300))

# %%
#SMARTS Azida
patt3= Chem.MolFromSmarts('[N;H0;$(N-[#6]);D2]=[N;D2]=[N;D1]')
azide = [x for x in mols if x.HasSubstructMatch(patt3)]
Draw.MolsToGridImage(list(azide), subImgSize=(300,300))

# %% [markdown]
# e) Establecer las reacciones de acoplamiento y llevar a cabo las enumeración de los compuestos.

# %%
#Sustitución nucleofílica
rxn=AllChem.ReactionFromSmarts('[#6;a;r5:1]-[$([NX3;H2;!$(NC=O)]),$([#16X2H]),$([OX2H]):2].[#35,#17]-[#6:3][C:4]#[C:5]>>[#6;a;r5:1]-[$([NX3;H]),$([#16X2]),$([OX2]):2]-[#6:3][C:4]#[C:5]')

prods1 = AllChem.EnumerateLibraryFromReaction(rxn,[het5,alkynes])
smis = list(set([Chem.MolToSmiles(x[0],isomericSmiles=True) for x in prods1]))

#Reacción de química click

rxn2= AllChem.ReactionFromSmarts('[#6:7][C:6]#[CH1:5].[#6:4]-[#7:3]=[N+]=[#7-]>>[#6:4]-[#7:3]-1-[#6:5]=[#6:6](-[#6:7])-[#7]=[#7]-1 |c:10,t:7|')
prods2 = AllChem.EnumerateLibraryFromReaction(rxn2,[[ Chem.MolFromSmiles(x) for x in smis ],azide])
smis2 = list(set([Chem.MolToSmiles(x[0],isomericSmiles=True) for x in prods2]))
len(smis2)
# Out:
# 7884

# %%
smis2
# Out:
# ['CC(Nc1nc2cc(Br)ccc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'COc1ccc(N2C=C(CNc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)Nc2ncc(Cc3ccc(F)c(F)c3)s2)N=N1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Sc2ccoc2C)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3ccccc3n2CC(C)C)N=N1',
#  'CCc1[nH]c(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc1-c1ccccc1',
#  'COc1ccccc1N1C=C(CNc2nc(-c3ccccc3)cs2)N=N1',
#  'COc1ccc(N2C=C(C(C)Nc3ncc(-c4cccc(Cl)c4)o3)N=N2)cc1',
#  'CC(Oc1cc(C(F)(F)F)sc1C(=O)O)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4ccccc4n3CC(C)C)N=N2)c1',
#  'COc1cccc(N2C=C(CNc3nc4c(F)ccc(F)c4s3)N=N2)c1',
#  'CCOc1ccc2[nH]c(SC(C)(C)C3=CN(Cc4cccc(C)c4)N=N3)nc2c1',
#  'CC(Oc1nc(-c2ccccc2)cs1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'Cc1ccc(N2C=C(C(C)Oc3ccsc3C(=O)O)N=N2)cc1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc(-c3ccccc3)cs2)N=N1',
#  'CC(C)([18O][13c]1[15n]c2cc(Cl)ccc2o1)C1=CN(c2ccccc2)N=N1',
#  'CC(=O)c1sccc1NCC1=CN(Cc2ccccc2C)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3ncc(Cc4cccc(F)c4)s3)N=N2)ccc2ccccc21',
#  'COc1cccc(N2C=C(CNc3nc(C)c(Cl)s3)N=N2)c1',
#  'CC(Nc1nc(C2CC2)c(Br)s1)C1=CN(Cc2ccccc2)N=N1',
#  'COc1ccccc1N1C=C(C(C)[18O][13c]2[15n]c3cc(Cl)ccc3o2)N=N1',
#  'CC(Nc1nc2ccc(Br)cc2s1)C1=CN(c2ccccc2F)N=N1',
#  'Cc1cccc(CN2C=C(CNc3nc4ccccc4s3)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Nc3nccs3)N=N2)cc1',
#  'Cc1ccc(N2C=C(CNc3nc4cc(Br)ccc4s3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)Sc3nc4c(F)cccc4s3)N=N2)c1',
#  'Fc1cccc(N2C=C(CNc3ncc(F)s3)N=N2)c1',
#  'COc1cccc(N2C=C(CSc3nc4ccccc4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc(-c4ccc(F)cc4F)cs3)N=N2)c1',
#  'C[n+]1c(N2C=C(C(C)(C)Oc3csc(C(=O)O)c3)N=N2)ccc2ccccc21',
#  'C1=C(COc2nccs2)N=NN1Cc1ccccc1',
#  'Cc1cccc(N2C=C(CNc3nc4ccccc4[nH]3)N=N2)c1',
#  'CCn1c(NC(C)C2=CN(c3cccc(OC)c3)N=N2)nc2ccccc21',
#  'COc1ccc(N2C=C(C(C)Nc3nc4cc(Br)ccc4s3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(s1)CCCC2)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(s3)CCCCCC4)N=N2)c1',
#  'Cc1[nH]c(NC(C)C2=CN(Cc3ccccc3)N=N2)nc1Cc1ccccc1',
#  'COc1ccccc1N1C=C(CNc2nc(CCl)cs2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(-c4ccccc4)cs3)N=N2)c1',
#  'CC(Nc1ncc(Cl)s1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2ncc(Cc3ccccc3)s2)N=N1',
#  'CCc1[nH]c(NCC2=CN(c3ccc(C)cc3)N=N2)nc1-c1ccccc1',
#  'CC(C)(Nc1nc(-c2c(F)cccc2F)cs1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CC(Oc1ccsc1C(=O)O)C1=CN(c2cccc(F)c2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Sc3nc4ccccc4s3)N=N2)ccc2ccccc21',
#  'CCCc1cnc(NCC2=CN(c3ccc(OC)cc3)N=N2)s1',
#  'Cc1ccc(N2C=C(C(C)Sc3nc4cc(F)ccc4o3)N=N2)cc1',
#  'CCc1cnc(NCC2=CN(c3cccc(OC)c3)N=N2)s1',
#  'CC(C)(Nc1nc(-c2c(F)cccc2F)cs1)C1=CN(CCN2CCCCC2)N=N1',
#  'CCn1c(SC(C)C2=CN(CCN3CCCCC3)N=N2)nc2ccccc21',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4c(s3)CCCCC4)N=N2)c1',
#  'CC(Nc1ncc(-c2ccc(F)cc2)[nH]1)C1=CN(Cc2ccccc2)N=N1',
#  'COc1ccc(N2C=C(CNc3ncc(F)s3)N=N2)cc1',
#  'CC(=O)c1sccc1NCC1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4c(s3)CC(C(C)(C)C)CC4)N=N2)cc1',
#  'CCn1c(NCC2=CN(c3ccccc3OC)N=N2)nc2ccccc21',
#  'CCc1[nH]c(NC(C)(C)C2=CN(c3ccccc3C)N=N2)nc1-c1ccccc1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3ccc(F)cc3o2)N=N1',
#  'CCn1c(NC(C)(C)C2=CN(c3cccc(F)c3)N=N2)nc2ccccc21',
#  'CC(C)(Nc1nc(-c2ccccc2)c[nH]1)C1=CN(c2ccccc2F)N=N1',
#  'CCCCn1c(NC(C)(C)C2=CN(c3cccc(C)c3)N=N2)nc2ccccc21',
#  'Fc1ccc(-c2cnc(NCC3=CN(c4cccc(F)c4)N=N3)[nH]2)cc1',
#  'CCCCn1c(NC(C)(C)C2=CN(CCN3CCCCC3)N=N2)nc2ccccc21',
#  'Cc1ccc(N2C=C(CNc3nc4c(F)cccc4s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(CNc2nc(C(F)(F)F)c(Br)s2)N=N1',
#  'Fc1ccc(N2C=C(CSc3nc4cc(F)ccc4o3)N=N2)cc1',
#  'Cc1sc(NC(C)(C)C2=CN(c3ccccc3F)N=N2)nc1-c1ccc(F)c(F)c1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nc3c(s2)-c2ccccc2CC3)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2ncc(-c3ccc(Br)cc3)o2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)Oc2nc3c(F)cccc3s2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc(-c4ccc(F)c(F)c4)cs3)N=N2)c1',
#  'CC(Nc1ncc(Cc2ccccc2)s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3ncc(-c4ccc(F)cc4)[nH]3)N=N2)c1',
#  'Clc1ccc2oc(NCC3=CN(c4ccccc4)N=N3)nc2c1',
#  'CC(C)(Sc1ncc[nH]1)C1=CN(c2ccccc2F)N=N1',
#  'COc1ccccc1N1C=C(C(C)Sc2nc3cc(OC(F)F)ccc3[nH]2)N=N1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(Cc4cccc(C)c4)N=N3)n2)cc1',
#  'CC(C)(Nc1nc2c(s1)CCCCCC2)C1=CN(CCN2CCCCC2)N=N1',
#  'CCCn1c(NC(C)(C)C2=CN(c3ccccc3C)N=N2)nc2ccccc21',
#  'CC(C)(Nc1ncc(Cc2cccc(F)c2)s1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cn1c(-c2ccccc2)cnc1NCC1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(C(F)(F)F)co3)N=N2)cc1',
#  'COc1ccccc1N1C=C(CSc2nc3cc(Br)ccc3o2)N=N1',
#  'CC(C)(Sc1nc2cccc(F)c2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CC(C)(Oc1nc2c(F)cccc2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CCc1[nH]c(NCC2=CN(c3ccc(OC)cc3)N=N2)nc1-c1ccccc1',
#  'Cc1sc(NCC2=CN(c3ccccc3F)N=N2)nc1-c1ccc(F)cc1',
#  'Cc1ccccc1-c1csc(NC(C)(C)C2=CN(c3ccccc3)N=N2)n1',
#  'CC(C)Cc1cnc(NCC2=CN(Cc3ccccc3)N=N2)s1',
#  'Cc1cccc(CN2C=C(CNc3ncc[nH]3)N=N2)c1',
#  'Cc1nc(NCC2=CN(CCN3CCCCC3)N=N2)sc1F',
#  'Cc1ccccc1CN1C=C(CSc2nc3cccc(F)c3s2)N=N1',
#  'Cc1sc(NC(C)C2=CN(Cc3ccccc3F)N=N2)nc1-c1ccc(F)cc1',
#  'Cc1cnc(NCC2=CN(CCN3CCCCC3)N=N2)s1',
#  'COc1cccc(N2C=C(CNc3nc4c(C)cc(C)cc4s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)Nc3ncc(-c4ccc(C)cc4)[nH]3)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc4c(Cl)cccc4s3)N=N2)cc1',
#  'CCc1cnc(NC(C)C2=CN(CCN3CCCCC3)N=N2)s1',
#  'CC(C)(Oc1nc2ccccc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'CCCc1nc(NC(C)(C)C2=CN(c3ccccc3C)N=N2)sc1CC',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(C(C)C)c(C)s3)N=N2)c1',
#  'Cc1ccc(CN2C=C(C(C)(C)Sc3nc(C)c(C)o3)N=N2)cc1',
#  'CC(Nc1nc2ccc(C(F)(F)F)cc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'C1=C(CNc2ncc[nH]2)N=NN1CCN1CCCCC1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc3c(F)cccc3s2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)ccc2ccccc21',
#  'COc1ccccc1N1C=C(C(C)Oc2csc(C(=O)O)c2)N=N1',
#  'Cc1sc(NC(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc1-c1ccc(F)c(F)c1',
#  'C[n+]1c(N2C=C(C(C)(C)Oc3cc(C(F)(F)F)sc3C(=O)O)N=N2)ccc2ccccc21',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc(Cc4ccccc4)c(C)[nH]3)N=N2)c1',
#  'CC(Sc1nc2cc(OC(F)F)ccc2[nH]1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Fc1cccc(N2C=C(CNc3ncc(Br)s3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2ncco2)N=N1',
#  'Cc1ccccc1CN1C=C(CNc2nc3ccc(Br)cc3s2)N=N1',
#  'Fc1ccc(N2C=C(CSc3nc4ccccc4s3)N=N2)cc1',
#  'CCCn1c(NCC2=CN(Cc3ccccc3F)N=N2)nc2ccccc21',
#  'Brc1sc(NCC2=CN(CCN3CCCCC3)N=N2)nc1C1CC1',
#  'Cc1cccc(N2C=C(C(C)Sc3ccoc3C)N=N2)c1',
#  'Cc1nc(NCC2=CN(c3ccc(F)cc3)N=N2)sc1F',
#  'Cc1ccc2nc(NCC3=CN(CCN4CCCCC4)N=N3)sc2c1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(CCN4CCCCC4)N=N3)n2)cc1',
#  'CCCCn1c(NCC2=CN(Cc3ccccc3F)N=N2)nc2ccccc21',
#  'Cc1ccc(N2C=C(C(C)Nc3ncc(-c4ccc(Cl)cc4)[nH]3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'Nc1ccc2[nH]c(SCC3=CN(CCN4CCCCC4)N=N3)nc2c1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4cc(Br)ccc4s3)N=N2)c1',
#  'CC(Oc1ccsc1C(=O)O)C1=CN(Cc2ccccc2)N=N1',
#  'FC(F)(F)c1cnc(NCC2=CN(c3ccccc3)N=N2)s1',
#  'Fc1cc(Cl)c2nc(NCC3=CN(c4ccccc4F)N=N3)sc2c1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3c[nH]c4ccccc34)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)Nc3nc4cc(C)ccc4[nH]3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(F)ccc(F)c2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'CCCn1c(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc2ccccc21',
#  'C1=C(CNc2nccs2)N=NN1CCN1CCCCC1',
#  'COc1ccc(N2C=C(C(C)[18O][13c]3[15n]c4cc(Cl)ccc4o3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)Sc3cc(C)oc3C)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(-c4ccc(F)c(C)c4)cs3)N=N2)cc1',
#  'Cc1cc(SCC2=CN(Cc3ccc(F)cc3)N=N2)c(C)o1',
#  'COc1cccc(N2C=C(CNc3nc(C)c(F)s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4ccc(Br)cc4s3)N=N2)c1',
#  'Cc1sc(NCC2=CN(Cc3ccccc3F)N=N2)nc1C(C)C',
#  'CC(Nc1nc2ccccc2[nH]1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Oc3nccs3)N=N2)cc1',
#  'Fc1ccccc1N1C=C(CNc2c[nH]c3ccccc23)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(-c4ccc(F)cc4F)cs3)N=N2)cc1',
#  'CC(Nc1ncco1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4ccc(Br)cc4s3)N=N2)cc1',
#  'Cc1cccc(N2C=C(C(C)Nc3ncc(-c4ccc(F)cc4)[nH]3)N=N2)c1',
#  'Cc1ccc(N2C=C(CNc3nc4cccc(Cl)c4[nH]3)N=N2)cc1',
#  'CC(Nc1nccn1C)C1=CN(c2ccccc2)N=N1',
#  'COc1ccc(N2C=C(C(C)Nc3nc4c(s3)CCCC4)N=N2)cc1',
#  'Cc1ccc(CN2C=C(C(C)Nc3ncc(-c4ccc(Cl)cc4)[nH]3)N=N2)cc1',
#  'CC(C)(Nc1ncc(-c2ccc(Br)cc2)o1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2ncc(Cl)s2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Sc3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'CCn1ccnc1SCC1=CN(c2ccccc2OC)N=N1',
#  'Fc1ccc2oc(SCC3=CN(c4ccccc4F)N=N3)nc2c1',
#  'Cc1cccc(N2C=C(CNc3nc4cccc(Cl)c4[nH]3)N=N2)c1',
#  'Cc1ccccc1N1C=C(C(C)Nc2nc(C(F)(F)F)co2)N=N1',
#  'Fc1cc(F)c2nc(NCC3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc3cc(F)ccc3s2)N=N1',
#  'Cc1nc(SCC2=CN(c3ccc(F)cc3)N=N2)oc1C',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4c(C)cc(Cl)cc4s3)N=N2)cc1',
#  'Fc1cccc(N2C=C(CNc3nc4c(Cl)cccc4s3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(Cc3ccccc3)c(C)[nH]2)N=N1',
#  'CCc1cnc(NC(C)(C)C2=CN(Cc3cccc(C)c3)N=N2)s1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Sc2nc3cc(OC(F)F)ccc3[nH]2)N=N1',
#  'Cc1cc2nc(NC(C)C3=CN(CCN4CCCCC4)N=N3)sc2cc1C',
#  'Fc1ccc(N2C=C(CNc3nc4c(s3)CCCCCC4)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)(C)Sc3nc4ccccc4s3)N=N2)c1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nc3ccc(Br)cc3s2)N=N1',
#  'CC(C)(Nc1nc2c(Br)cc(F)cc2s1)C1=CN(c2ccccc2F)N=N1',
#  'CC(Nc1nc2c(I)cccc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'CCn1c(SC(C)C2=CN(c3ccc(OC)cc3)N=N2)nc2ccccc21',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc(C)co3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(F)cc(F)cc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'Fc1ccc(CN2C=C(CSc3nc4cccc(Cl)c4o3)N=N2)cc1',
#  'Cc1nc(NC(C)(C)C2=CN(c3ccccc3F)N=N2)sc1F',
#  'Cc1ccccc1CN1C=C(CNc2nc3ccc(F)cc3o2)N=N1',
#  'Fc1ccccc1-c1csc(NCC2=CN(Cc3ccccc3)N=N2)n1',
#  'CC(C)(Sc1nc2cccc(F)c2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'CC(C)Cn1c(NCC2=CN(c3cccc(F)c3)N=N2)nc2ccccc21',
#  'CC(C)(Nc1nc(-c2ccccc2)cs1)C1=CN(Cc2ccccc2)N=N1',
#  'CC(C)(Nc1nc2ccc(Cl)cc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(Nc1nc2c(Cl)cccc2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc3c(s2)-c2ccccc2CC3)N=N1',
#  'CC(Nc1nccs1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4ccccc4n3C(C)C)N=N2)c1',
#  'CC(C)(Oc1cc(C(F)(F)F)sc1C(=O)O)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nccn2C)N=N1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4cc(C)c(C)cc4[nH]3)N=N2)c1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nccs2)N=N1',
#  'CC(Sc1nc2cc(Cl)ccc2[nH]1)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(C)(Nc1ncc(-c2ccc(Br)cc2)[nH]1)C1=CN(c2cccc(F)c2)N=N1',
#  'CCCc1nc(NC(C)C2=CN(CCN3CCCCC3)N=N2)sc1CC',
#  'Cc1ccc(N2C=C(C(C)Nc3nc(C)cs3)N=N2)cc1',
#  'CCn1c(SC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc2ccccc21',
#  'Cc1ccc(N2C=C(C(C)Nc3cscc3N)N=N2)cc1',
#  'CCn1c(SCC2=CN(c3cccc(OC)c3)N=N2)nc2ccccc21',
#  'CCn1c(SCC2=CN(c3cccc(C)c3)N=N2)nc2ccccc21',
#  'CCn1ccnc1SC(C)(C)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(Nc1cscc1N)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(C)cccc4s3)N=N2)cc1',
#  'Cn1c(SCC2=CN(Cc3ccc(F)cc3)N=N2)nc2ccccc21',
#  'CC(Nc1nc(C(C)(C)C)c(Br)s1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(c4ccc(C)cc4)N=N3)n2)cc1',
#  'Fc1ccc(N2C=C(CNc3nccs3)N=N2)cc1',
#  'COc1ccc(N2C=C(CNc3ncc(Cc4cccc(F)c4)s3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(CNc3ncc(Cl)s3)N=N2)c1',
#  'Cc1sc(NC(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc1-c1ccc(F)c(F)c1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc3c(Br)cccc3s2)N=N1',
#  'Fc1cccc(N2C=C(CNc3nc4ccc(Cl)cc4s3)N=N2)c1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc(-c3ccc(F)c(F)c3)c(C)s2)N=N1',
#  'Cn1c(SC(C)(C)C2=CN(c3ccccc3F)N=N2)nc2ccccc21',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4cc(C)c(C)cc4[nH]3)N=N2)c1',
#  'Cc1ccccc1N1C=C(C(C)Nc2nc(-c3ccc(F)c(F)c3)c(C)s2)N=N1',
#  'CC(C)(Sc1nc2cccc(F)c2s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccccc1N1C=C(CNc2nc3ccccc3o2)N=N1',
#  'CC(Nc1nc2c(s1)Cc1ccccc1-2)C1=CN(c2cccc(F)c2)N=N1',
#  'CC(Nc1ncc(C(C)C)s1)C1=CN(c2ccccc2F)N=N1',
#  'CC(C)(Nc1nc(C(F)(F)F)co1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(N2C=C(C(C)Nc3ncc(-c4cccc(Cl)c4)o3)N=N2)c1',
#  'Fc1cccc(N2C=C(CNc3nc4cc(Br)ccc4s3)N=N2)c1',
#  'COc1cccc(N2C=C(CNc3nccs3)N=N2)c1',
#  'CC(C)(Nc1nc2c(s1)CCCCCC2)C1=CN(c2ccccc2F)N=N1',
#  'CCOc1ccc2[nH]c(SCC3=CN(c4ccccc4OC)N=N3)nc2c1',
#  'CC(Nc1ncc(Cc2cc(F)cc(F)c2)s1)C1=CN(c2ccccc2F)N=N1',
#  'COc1cccc(N2C=C(C(C)Oc3cc(C(F)(F)F)sc3C(=O)O)N=N2)c1',
#  'CCc1nc(NC(C)(C)C2=CN(c3ccccc3)N=N2)sc1C',
#  'Cc1ccc(CN2C=C(C(C)(C)[18O][13c]3nc4cc(Cl)ccc4o3)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2ncc(Cc3ccccc3)s2)N=N1',
#  'CCn1c(NC(C)(C)C2=CN(c3ccccc3OC)N=N2)nc2ccccc21',
#  'Cc1sc(NC(C)(C)C2=CN(c3ccc(F)cc3)N=N2)nc1-c1ccc(F)c(F)c1',
#  'Cc1cccc(N2C=C(CNc3nc4c(s3)-c3ccccc3CC4)N=N2)c1',
#  'Cc1ccc(CN2C=C(C(C)(C)Sc3nc4cc(N)ccc4[nH]3)N=N2)cc1',
#  'CC(C)(Oc1nccs1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(N2C=C(CSc3nc4cc(C)ccc4[nH]3)N=N2)c1',
#  'CCCc1nc(NC(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)sc1CC',
#  'Cc1ccccc1N1C=C(C(C)(C)Oc2cc(C(F)(F)F)sc2C(=O)O)N=N1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(c4ccc5ccccc5[n+]4C)N=N3)n2)cc1',
#  'CCc1nc(NCC2=CN(c3ccc(OC)cc3)N=N2)sc1C',
#  'CCCc1cnc(NC(C)(C)C2=CN(c3ccccc3C)N=N2)s1',
#  'CC(Nc1nc2c(Cl)cc(F)cc2s1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'COc1ccc(N2C=C(CNc3ncc(-c4ccc(Br)cc4)[nH]3)N=N2)cc1',
#  'Cc1cc(C)c2nc(NC(C)(C)C3=CN(c4ccccc4)N=N3)sc2c1',
#  'CC(Nc1cscc1N)C1=CN(Cc2ccccc2)N=N1',
#  'CC(Nc1nc2c(s1)CCCCCC2)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1ccc(CN2C=C(CSc3c[nH]c4ccccc34)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(C(C)Sc2nc3cc(OC(F)F)ccc3[nH]2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4ccccc4s3)N=N2)c1',
#  'CC(Sc1nc2cccc(Cl)c2o1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'CC(C)(Nc1nc2cc(Br)ccc2[nH]1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1nc(NCC2=CN(c3ccccc3)N=N2)sc1C',
#  'CC(Nc1ncc(Cc2ccc(F)cc2F)s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc(C(F)(F)F)cs2)N=N1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc(-c3ccc(F)cc3)c(C)s2)N=N1',
#  'CC(Nc1nc(-c2ccc(F)cc2F)cs1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc4cc(Cl)ccc4[nH]3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4c(F)cc(Br)cc4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(CNc3ncc(-c4ccccc4)n3C)N=N2)c1',
#  'Cc1cc(SC(C)(C)C2=CN(Cc3ccccc3C)N=N2)c(C)o1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nc3ccc(F)cc3o2)N=N1',
#  'Cc1coc(NCC2=CN(c3ccccc3C)N=N2)n1',
#  'CC(Nc1ncc(-c2ccccc2)n1C)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cnc(NC(C)(C)C2=CN(c3ccccc3)N=N2)s1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4ccccc4o3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)Nc2ncc(-c3cccc(Cl)c3)o2)N=N1',
#  'CC(C)(Nc1nc2cc(Cl)ccc2[nH]1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1cccc2sc(NCC3=CN(c4ccccc4)N=N3)nc12',
#  'Fc1ccccc1CN1C=C(CNc2c[nH]c3ccccc23)N=N1',
#  'COc1ccc(N2C=C(CNc3nc(C(F)(F)F)cs3)N=N2)cc1',
#  'Brc1ccc2[nH]c(NCC3=CN(CCN4CCCCC4)N=N3)nc2c1',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc(C(F)(F)F)co3)N=N2)cc1',
#  'Fc1ccc(N2C=C(CNc3nc4c(s3)-c3ccccc3CC4)N=N2)cc1',
#  'CC(Nc1ncc(Cc2ccc(F)c(F)c2)s1)C1=CN(c2ccccc2F)N=N1',
#  'CC1CCc2nc(NC(C)C3=CN(CCN4CCCCC4)N=N3)sc2C1',
#  'CC(Nc1nc2ccc(F)cc2o1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(C(C)(C)C)c(Br)s3)N=N2)cc1',
#  'Cc1ccc(CN2C=C(CSc3nc4cc(N)ccc4[nH]3)N=N2)cc1',
#  'CC(C)(Nc1nc(C2CC2)c(Br)s1)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(C)(Nc1nc(C(F)(F)F)co1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1nc(NCC2=CN(Cc3ccc(F)cc3)N=N2)sc1Br',
#  'CC(Nc1ncc(Br)s1)C1=CN(CCN2CCCCC2)N=N1',
#  'CCc1csc(NCC2=CN(c3ccc(F)cc3)N=N2)n1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(s3)CCCCC4)N=N2)cc1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(c4ccccc4F)N=N3)n2)cc1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4c(Cl)cccc4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4cc(C)ccc4[nH]3)N=N2)c1',
#  'CC(Nc1nc2c(F)cc(Br)cc2s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(Nc1nc(-c2ccccc2)cs1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CC(Nc1ncc(-c2ccc(F)cc2)[nH]1)C1=CN(c2ccc(F)cc2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3cc(Br)ccc3s2)N=N1',
#  'Fc1ccc(CN2C=C(CNc3nc(C4CC4)cs3)N=N2)cc1',
#  'CCCc1cnc(NCC2=CN(c3ccccc3F)N=N2)s1',
#  'CC(Nc1nc2ccccc2n1C)C1=CN(c2cccc(F)c2)N=N1',
#  'CC(C)c1nc(NC(C)(C)C2=CN(c3ccc(F)cc3)N=N2)sc1Br',
#  'COc1cccc(N2C=C(C(C)Nc3ncc(Br)s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4c(Cl)cc(F)cc4s3)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Sc3nc4ccccc4o3)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc3ccccc3o2)N=N1',
#  'CC(C)c1cnc(NCC2=CN(c3cccc(F)c3)N=N2)s1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc(C)co2)N=N1',
#  'C1=C(CNc2nc3ccccc3s2)N=NN1Cc1ccccc1',
#  'CC(Sc1nc2cccc(F)c2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'COc1ccccc1N1C=C(CNc2nc(C)c(C)o2)N=N1',
#  'CC(Nc1ncc(Cc2ccc(F)cc2F)s1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccc2[nH]c(NC(C)(C)C3=CN(CCN4CCCCC4)N=N3)nc2c1',
#  'CC(Nc1ncc(Br)s1)C1=CN(c2ccccc2F)N=N1',
#  'CCCCn1c(NCC2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc2ccccc21',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3ncc(-c4ccc(Br)cc4)[nH]3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3ccccc3o2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)c1',
#  'Brc1ccc(-c2cnc(NCC3=CN(c4ccccc4)N=N3)[nH]2)cc1',
#  'CCOc1ccc2[nH]c(SC(C)(C)C3=CN(c4cccc(C)c4)N=N3)nc2c1',
#  'CC(Oc1nccs1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1sc(NC(C)C2=CN(CCN3CCCCC3)N=N2)nc1-c1ccc(F)c(F)c1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2ncco2)N=N1',
#  'Cc1ccc(N2C=C(CNc3ncc(C)s3)N=N2)cc1',
#  'Cc1ccc2[nH]c(SC(C)(C)C3=CN(c4ccccc4F)N=N3)nc2c1',
#  'COc1ccccc1N1C=C(CNc2ncc(Cc3ccccc3)s2)N=N1',
#  'C1=C(COc2nccs2)N=NN1c1ccccc1',
#  'Cc1cccc(CN2C=C(C(C)[18O][13c]3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'CCn1c(SCC2=CN(c3ccccc3OC)N=N2)nc2ccccc21',
#  'Cc1sc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc1-c1ccccc1',
#  'Cc1ccccc1N1C=C(CSc2nc3cc(Cl)ccc3o2)N=N1',
#  'C1=C(CNc2nc3c(s2)Cc2ccccc2-3)N=NN1CCN1CCCCC1',
#  'Cc1ccc(-c2csc(NC(C)(C)C3=CN(c4cccc(F)c4)N=N3)n2)cc1',
#  'CC(C)(Nc1nc2c(F)cc(F)cc2s1)C1=CN(c2ccccc2)N=N1',
#  'CC(Nc1ncc(-c2ccc(Br)cc2)o1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc(-c4ccccc4)cs3)N=N2)c1',
#  'Cc1ccc(CN2C=C(CNc3nc4c(s3)CCCC4)N=N2)cc1',
#  'Cc1ccc(N2C=C(CNc3ncc(-c4ccc(F)cc4)[nH]3)N=N2)cc1',
#  'C[n+]1c(N2C=C(C(C)(C)Sc3nc4cc(N)ccc4[nH]3)N=N2)ccc2ccccc21',
#  'CC(C)(Nc1nc2c(I)cccc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccccc1N1C=C(CNc2ncc(-c3ccccc3)n2C)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(C4CC4)c(Br)s3)N=N2)cc1',
#  'Cc1cc(C)c2nc(NC(C)C3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'CC(C)(Nc1cscc1N)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccc(N2C=C(COc3nc4ccccc4s3)N=N2)cc1',
#  'CC(C)c1nc(NCC2=CN(Cc3ccccc3)N=N2)sc1Br',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc4ccc(F)cc4s3)N=N2)cc1',
#  'CCc1[nH]c(NC(C)C2=CN(Cc3ccccc3C)N=N2)nc1-c1ccccc1',
#  'Cc1sc(NC(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc1-c1ccc(F)cc1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Nc3ncc[nH]3)N=N2)cc1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(C)cc(C)cc4s3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(s1)-c1ccccc1CC2)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Sc3nc4c(F)cccc4s3)N=N2)cc1',
#  'CC(Nc1nc2c(Cl)cccc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc3c(I)cccc3s2)N=N1',
#  'Cc1cccc(N2C=C(COc3ccsc3C(=O)O)N=N2)c1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nccn3C)N=N2)c1',
#  'Cc1sc(NCC2=CN(c3ccccc3F)N=N2)nc1-c1ccccc1',
#  'Cc1cccc(N2C=C(CNc3nc4c(F)cc(F)cc4s3)N=N2)c1',
#  'COc1ccc2[nH]c(SCC3=CN(c4ccc(F)cc4)N=N3)nc2c1',
#  'Cc1ccc2[nH]c(SC(C)C3=CN(c4ccc(F)cc4)N=N3)nc2c1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(-c3ccc(F)cc3F)cs2)N=N1',
#  'Cc1cnc(NC(C)(C)C2=CN(c3cccc(F)c3)N=N2)[nH]1',
#  'Cc1cccc(N2C=C(C(C)(C)[18O][13c]3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'CCc1ccc2nc(NC(C)C3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'Cc1cccc(CN2C=C(CNc3nc(C)co3)N=N2)c1',
#  'CCCc1cnc(NC(C)(C)C2=CN(c3cccc(C)c3)N=N2)s1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(-c4ccccc4F)cs3)N=N2)c1',
#  'CC(Oc1nccs1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'CC(C)(Sc1nc2cccc(Cl)c2o1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1cc2nc(NC(C)C3=CN(Cc4ccccc4F)N=N3)[nH]c2cc1C',
#  'Cc1ccc(-c2cnc(NCC3=CN(Cc4ccc(F)cc4)N=N3)[nH]2)cc1',
#  'Cc1cccc(N2C=C(C(C)(C)Sc3nc4cc(F)ccc4o3)N=N2)c1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc(C3CC3)c(Br)s2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3nc4c(s3)CCCCC4)N=N2)ccc2ccccc21',
#  'CCCn1c(NCC2=CN(c3ccc(C)cc3)N=N2)nc2ccccc21',
#  'CC(Nc1ncc(-c2ccc(Br)cc2)o1)C1=CN(c2ccccc2)N=N1',
#  'CC(C)(Oc1nc2c(F)cccc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1cccc(N2C=C(CNc3nc4c(s3)CC(C(C)(C)C)CC4)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)Nc3nc(C4CC4)c(Br)s3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(s1)-c1ccccc1CC2)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4cc(Br)ccc4[nH]3)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2cscc2N)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4cc(Cl)ccc4[nH]3)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(CNc2nc3ccccc3n2C)N=N1',
#  'CCn1ccnc1SC(C)C1=CN(Cc2ccccc2C)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc(C(F)(F)F)co2)N=N1',
#  'Cc1ccc(N2C=C(CNc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)cc1',
#  'CC(Nc1ncc(Cc2ccccc2)s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Nc3ncc(Cc4ccc(F)c(F)c4)s3)N=N2)cc1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4ccc(Cl)cc4s3)N=N2)cc1',
#  'Fc1ccc(N2C=C(CNc3ncc(F)s3)N=N2)cc1',
#  'COc1cccc(N2C=C(CNc3nc(-c4c(F)cccc4F)cs3)N=N2)c1',
#  'COc1ccccc1N1C=C(CNc2nc3c(F)cccc3s2)N=N1',
#  'CC(C)(Sc1nc2cc(Br)ccc2o1)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(Nc1nc(C(F)(F)F)c(Br)s1)C1=CN(Cc2ccccc2)N=N1',
#  'CCCc1nc(NCC2=CN(CCN3CCCCC3)N=N2)sc1CC',
#  'Fc1cc(Br)c2nc(NCC3=CN(c4ccccc4)N=N3)sc2c1',
#  'CCc1cccc2sc(NCC3=CN(c4ccccc4OC)N=N3)nc12',
#  'Cc1cnc(NCC2=CN(c3ccccc3C)N=N2)[nH]1',
#  'CCOc1ccc2[nH]c(SCC3=CN(c4cccc(C)c4)N=N3)nc2c1',
#  'CCCc1cnc(NCC2=CN(c3cccc(C)c3)N=N2)s1',
#  'Cc1ccccc1N1C=C(C(C)Sc2nc3ccccc3n2C)N=N1',
#  'Fc1ccc(CN2C=C(CNc3nc(-c4c(F)cccc4F)cs3)N=N2)cc1',
#  'CCc1cnc(NC(C)C2=CN(c3ccc(C)cc3)N=N2)s1',
#  'CC(C)(Sc1nc2cc(N)ccc2[nH]1)C1=CN(Cc2ccccc2F)N=N1',
#  'CCc1cnc(NCC2=CN(Cc3ccccc3C)N=N2)s1',
#  'Cc1cccc(CN2C=C(CSc3ncc[nH]3)N=N2)c1',
#  'CCc1[nH]c(NCC2=CN(c3ccccc3C)N=N2)nc1-c1ccccc1',
#  'Cc1cc(Cl)cc2sc(NC(C)C3=CN(Cc4ccccc4)N=N3)nc12',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc(C(F)(F)F)c(Br)s2)N=N1',
#  'CCCn1c(NC(C)(C)C2=CN(c3cccc(OC)c3)N=N2)nc2ccccc21',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nc3ccc(C(F)(F)F)cc3s2)N=N1',
#  'Cc1cc(-c2csc(NC(C)(C)C3=CN(c4ccccc4)N=N3)n2)ccc1F',
#  'Cc1cccc(CN2C=C(CSc3nc4ccccc4s3)N=N2)c1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(Cc4ccccc4C)N=N3)n2)cc1',
#  'CC(C)(Sc1nc2cc(N)ccc2[nH]1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(COc3nccs3)N=N2)cc1',
#  'COc1ccc2[nH]c(SCC3=CN(Cc4ccccc4C)N=N3)nc2c1',
#  'Cc1cc2nc(NC(C)(C)C3=CN(Cc4ccccc4)N=N3)sc2cc1C',
#  'CC(Sc1nc2cccc(Cl)c2o1)C1=CN(c2ccccc2)N=N1',
#  'Cc1sc(NC(C)(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc1-c1ccccc1',
#  'CCn1c(NCC2=CN(CCN3CCCCC3)N=N2)nc2ccccc21',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3c(Cl)ccc(F)c3s2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4c(C)cc(C)cc4s3)N=N2)c1',
#  'COc1ccc(N2C=C(CNc3nc4ccccc4n3C)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)(C)Sc3nc(C)c(C)o3)N=N2)cc1',
#  'CC(C)(Nc1cscc1N)C1=CN(c2ccccc2)N=N1',
#  'CC(C)(Nc1nc2c(s1)CCc1ccccc1-2)C1=CN(c2cccc(F)c2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Sc3cc(C)oc3C)N=N2)c1',
#  'Cc1ccc(CN2C=C(C(C)Nc3ncc(Cc4ccc(F)c(F)c4)s3)N=N2)cc1',
#  'COc1cccc(N2C=C(CNc3nc(C(C)C)c(Br)s3)N=N2)c1',
#  'Fc1ccc(N2C=C(CNc3nc4c(I)cccc4s3)N=N2)cc1',
#  'Cc1nc(NCC2=CN(c3ccccc3F)N=N2)oc1C',
#  'CC(C)(C)c1nc(NCC2=CN(Cc3ccccc3)N=N2)sc1Br',
#  'COc1ccc2[nH]c(SCC3=CN(c4ccccc4)N=N3)nc2c1',
#  'Cc1cnc(NC(C)C2=CN(c3ccccc3F)N=N2)[nH]1',
#  'CC([18O][13c]1nc2cc(Cl)ccc2o1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)cc1',
#  'CCCc1cnc(NCC2=CN(Cc3ccccc3)N=N2)s1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4c(F)ccc(F)c4s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)Nc3ncc(-c4ccccc4)n3C)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc(-c4ccc(F)cc4)c(C)s3)N=N2)cc1',
#  'COc1ccccc1N1C=C(C(C)Nc2ncc(Cl)s2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)[18O][13c]3[15n]c4cc(Cl)ccc4o3)N=N2)cc1',
#  'CC(Nc1nc(C(C)(C)C)c(Br)s1)C1=CN(c2ccccc2)N=N1',
#  'CC(Oc1csc(C(=O)O)c1)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(C)(Nc1nc2cc(Br)ccc2[nH]1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccc(-c2csc(NC(C)(C)C3=CN(Cc4ccccc4F)N=N3)n2)cc1',
#  'Cc1cc2nc(NCC3=CN(c4ccc5ccccc5[n+]4C)N=N3)[nH]c2cc1C',
#  'CC(C)(Nc1ncc(Cc2cccc(F)c2)s1)C1=CN(Cc2ccccc2)N=N1',
#  'CC(Nc1ncc(C(F)(F)F)s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(CSc3nc4cc(F)ccc4o3)N=N2)cc1',
#  'C[n+]1c(N2C=C(CNc3ncc(-c4ccc(Br)cc4)[nH]3)N=N2)ccc2ccccc21',
#  'COc1cccc(N2C=C(CNc3nc4c(F)cc(F)cc4s3)N=N2)c1',
#  'CC(C)c1nc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)sc1Br',
#  'CCc1ccc2nc(NCC3=CN(c4ccccc4F)N=N3)sc2c1',
#  'Cc1cccc(CN2C=C(CNc3ncc(CC(C)C)s3)N=N2)c1',
#  'Fc1ccc(N2C=C(C[18O][13c]3[15n]c4cc(Cl)ccc4o3)N=N2)cc1',
#  'COc1ccccc1N1C=C(CNc2nc3c(s2)CCCC3)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc4ccccc4o3)N=N2)cc1',
#  'CC(C)n1c(NCC2=CN(c3ccc(F)cc3)N=N2)nc2ccccc21',
#  'Cc1cccc(CN2C=C(C(C)Nc3ncc(C(F)(F)F)s3)N=N2)c1',
#  'CC(C)(Nc1nc2c(s1)CCc1ccccc1-2)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(=O)c1sccc1NC(C)(C)C1=CN(c2ccc(C)cc2)N=N1',
#  'COc1cccc(N2C=C(CNc3nc4ccccc4[nH]3)N=N2)c1',
#  'CCc1nc(NC(C)(C)C2=CN(c3ccc(OC)cc3)N=N2)sc1C',
#  'COc1ccccc1N1C=C(CNc2nc3c(s2)CCC3)N=N1',
#  'Cc1cccc(CN2C=C(CNc3nc(C(C)C)c(Br)s3)N=N2)c1',
#  'Cc1ccc(-c2csc(NCC3=CN(c4ccccc4C)N=N3)n2)cc1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3ncc(-c4ccc(F)cc4)[nH]3)N=N2)cc1',
#  'Cn1c(-c2ccccc2)cnc1NC(C)(C)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Oc3cc(C(F)(F)F)sc3C(=O)O)N=N2)cc1',
#  'Cc1csc(NC(C)C2=CN(Cc3ccccc3F)N=N2)n1',
#  'COc1ccc(N2C=C(CNc3nc4ccccc4n3Cc3ccccc3)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)Nc3nc(C)c(Cl)s3)N=N2)cc1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2ncc(C(F)(F)F)s2)N=N1',
#  'CC(C)(Nc1nc(C(F)(F)F)c(Br)s1)C1=CN(CCN2CCCCC2)N=N1',
#  'Fc1ccc(-c2cnc(NCC3=CN(c4ccccc4F)N=N3)[nH]2)cc1',
#  'Cc1cc(-c2csc(NCC3=CN(c4cccc(F)c4)N=N3)n2)ccc1F',
#  'COc1ccc(N2C=C(C(C)(C)Sc3nc4cc(F)ccc4o3)N=N2)cc1',
#  'CCCc1cnc(NC(C)(C)C2=CN(c3ccccc3)N=N2)s1',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc(C(C)(C)C)c(Br)s3)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)Sc3nc(-c4ccccc4)c[nH]3)N=N2)cc1',
#  'CC(C)n1c(NC(C)(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc2ccccc21',
#  'Cc1cccc2sc(NCC3=CN(Cc4ccc(F)cc4)N=N3)nc12',
#  'Ic1cccc2sc(NCC3=CN(Cc4ccccc4)N=N3)nc12',
#  'COc1ccc(N2C=C(C(C)Nc3nc4ccccc4[nH]3)N=N2)cc1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2ncc(-c3ccc(F)cc3)[nH]2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(C(F)(F)F)co3)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)(C)Sc3nc4cc(N)ccc4[nH]3)N=N2)cc1',
#  'CC(C)(Sc1nc2cc(Cl)ccc2o1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc4ccccc4[nH]3)N=N2)cc1',
#  'CC(Nc1nc2ccc(Cl)cc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'CCCCn1c(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)nc2ccccc21',
#  'CCc1cnc(NC(C)(C)C2=CN(c3ccc(OC)cc3)N=N2)s1',
#  'CC(Sc1nc2cc(Cl)ccc2o1)C1=CN(c2ccccc2)N=N1',
#  'CC(C)(Nc1nc2c(C(F)(F)F)cccc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccccc1-c1csc(NC(C)C2=CN(Cc3ccc(F)cc3)N=N2)n1',
#  'COc1ccccc1N1C=C(CSc2nc3cc(Cl)ccc3[nH]2)N=N1',
#  'CCc1csc(NC(C)C2=CN(c3ccccc3F)N=N2)n1',
#  'Cc1occc1SC(C)(C)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc4cc(F)ccc4s3)N=N2)cc1',
#  'CC([18O][13c]1[15n]c2cc(Cl)ccc2o1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccccc1N1C=C(CSc2nc3cccc(F)c3s2)N=N1',
#  'CC(C)(Sc1nc2cccc(Cl)c2o1)C1=CN(c2ccccc2)N=N1',
#  'CC(Nc1nccn1C)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(Nc1nc2c(Br)cc(F)cc2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Fc1ccc(CN2C=C(CSc3nc4cc(Cl)ccc4o3)N=N2)cc1',
#  'Fc1cccc(N2C=C(CNc3nc4c(F)cc(Br)cc4s3)N=N2)c1',
#  'CCn1c(SCC2=CN(Cc3cccc(C)c3)N=N2)nc2ccccc21',
#  'Cc1cc(SCC2=CN(Cc3ccccc3)N=N2)c(C)o1',
#  'Cc1ccccc1CN1C=C(CNc2nc3cc(Br)ccc3s2)N=N1',
#  'CC(C)(C)c1nc(NCC2=CN(c3ccccc3)N=N2)sc1Br',
#  'CC(Nc1nc(-c2ccccc2F)cs1)C1=CN(Cc2ccccc2)N=N1',
#  'CC(C)(Nc1ncc(-c2ccc(Br)cc2)[nH]1)C1=CN(c2ccccc2F)N=N1',
#  'CC(Nc1ncc[nH]1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'COc1ccccc1N1C=C(C(C)Sc2ncc[nH]2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(-c4ccccc4)c[nH]3)N=N2)cc1',
#  'CC(C)c1cnc(NC(C)(C)C2=CN(c3ccc(F)cc3)N=N2)s1',
#  'Cc1cnc(NC(C)C2=CN(c3ccc(F)cc3)N=N2)s1',
#  'C[n+]1c(N2C=C(CNc3nc(C(F)(F)F)co3)N=N2)ccc2ccccc21',
#  'Fc1ccccc1N1C=C(CNc2nccs2)N=N1',
#  'CC(Oc1csc(C(=O)O)c1)C1=CN(c2ccccc2F)N=N1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(Br)cccc4s3)N=N2)c1',
#  'Cc1sc(NCC2=CN(Cc3ccccc3)N=N2)nc1-c1ccccc1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4ccccc4s3)N=N2)c1',
#  'Fc1ccc(CN2C=C(CNc3nc4c(s3)CCCCC4)N=N2)cc1',
#  'CC(Nc1nc2c(Br)cccc2s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1cccc(N2C=C(CNc3ncc[nH]3)N=N2)c1',
#  'C[n+]1c(N2C=C(CNc3nc(CCl)cs3)N=N2)ccc2ccccc21',
#  'COc1ccc(N2C=C(C(C)Nc3nc(C(C)C)c(Br)s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(CNc2nc(C(F)(F)F)cs2)N=N1',
#  'Cc1[nH]c(NCC2=CN(CCN3CCCCC3)N=N2)nc1Cc1ccccc1',
#  'CCc1ccc2nc(NC(C)(C)C3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'CC(Nc1ncc(Cl)s1)C1=CN(c2ccccc2)N=N1',
#  'CC(C)(Nc1nc2cc(Br)ccc2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3cc(Cl)ccc3[nH]2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3ncc(Br)s3)N=N2)cc1',
#  'Cc1cnc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)[nH]1',
#  'CCc1cnc(NCC2=CN(c3ccc(F)cc3)N=N2)s1',
#  'COc1ccc(N2C=C(C(C)Nc3nc4c(C)cc(C)cc4s3)N=N2)cc1',
#  'CC(C)(Nc1nc2ccc(Cl)cc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4cc(Cl)ccc4[nH]3)N=N2)c1',
#  'CC(Nc1nc(C(F)(F)F)c(Br)s1)C1=CN(c2cccc(F)c2)N=N1',
#  'CC(C)(Nc1ncc[nH]1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cccc(CN2C=C(CNc3nc4ccccc4n3CC(C)C)N=N2)c1',
#  'CCc1nc(NC(C)C2=CN(c3cccc(C)c3)N=N2)sc1C',
#  'Cc1ccc(CN2C=C(CSc3nc4ccccc4n3C)N=N2)cc1',
#  'CC(Nc1ncc[nH]1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccc(N2C=C(CNc3nc4c(C(F)(F)F)cccc4s3)N=N2)cc1',
#  'CC(=O)c1sccc1NC(C)C1=CN(c2cccc(C)c2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Sc3nc4cc(C)ccc4[nH]3)N=N2)c1',
#  'Cc1occc1SCC1=CN(Cc2ccccc2)N=N1',
#  'COc1ccccc1N1C=C(CNc2nc(-c3ccc(C)cc3)cs2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)(C)Oc3nccs3)N=N2)cc1',
#  'CC(C)(Nc1nc2ccccc2o1)C1=CN(CCN2CCCCC2)N=N1',
#  'Fc1cccc(N2C=C(CNc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1sc(NCC2=CN(c3ccc(F)cc3)N=N2)nc1-c1ccccc1',
#  'COc1cccc(N2C=C(COc3nc4ccccc4s3)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc4cc(Cl)ccc4o3)N=N2)cc1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)cc1',
#  'CC(Sc1nc2ccccc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'COc1ccc(N2C=C(CNc3nc4cc(Br)ccc4[nH]3)N=N2)cc1',
#  'CC(C)(Sc1nc2ccccc2o1)C1=CN(CCN2CCCCC2)N=N1',
#  'CC(C)(Nc1nc2c(F)cc(Br)cc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1cccc(N2C=C(C(C)Nc3ncc(Cc4cccc(F)c4)s3)N=N2)c1',
#  'CC(C)(Sc1nc2cc(F)ccc2o1)C1=CN(c2ccccc2)N=N1',
#  'CCc1cccc2sc(NC(C)(C)C3=CN(c4ccc5ccccc5[n+]4C)N=N3)nc12',
#  'Fc1cccc(N2C=C(C[18O][13c]3[15n]c4cc(Cl)ccc4o3)N=N2)c1',
#  'Cc1nc(NC(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)sc1C',
#  'Cc1occc1SCC1=CN(c2ccccc2)N=N1',
#  'Cc1cccc2sc(NCC3=CN(Cc4ccccc4F)N=N3)nc12',
#  'Fc1ccc(N2C=C(CNc3nc4c(s3)Cc3ccccc3-4)N=N2)cc1',
#  'CCOc1ccc2[nH]c(SC(C)(C)C3=CN(Cc4ccc(C)cc4)N=N3)nc2c1',
#  'CC(C)(Nc1nc2ccc(Br)cc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1coc(NC(C)C2=CN(CCN3CCCCC3)N=N2)n1',
#  'Cc1cccc(N2C=C(C(C)Sc3nc4c(F)cccc4s3)N=N2)c1',
#  'Cc1ccc(CN2C=C(CNc3nc4c(C)cc(Cl)cc4s3)N=N2)cc1',
#  'CC(Sc1nc2c(F)cccc2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'CCc1cccc2sc(NC(C)(C)C3=CN(c4cccc(F)c4)N=N3)nc12',
#  'Cc1cc(SC(C)C2=CN(Cc3ccccc3C)N=N2)c(C)o1',
#  'CC(C)(Nc1nc2ccc(Br)cc2s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'COc1ccccc1N1C=C(CNc2nc3ccccc3s2)N=N1',
#  'Nc1cscc1NCC1=CN(Cc2ccccc2F)N=N1',
#  'CC1CCc2nc(NC(C)C3=CN(Cc4ccccc4)N=N3)sc2C1',
#  'Cc1ccc(CN2C=C(C(C)Nc3ncc(Cl)s3)N=N2)cc1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc(C(F)(F)F)co3)N=N2)c1',
#  'COc1ccccc1N1C=C(CNc2cc(C)sc2C#N)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3cc(Cl)ccc3o2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)Nc3ncc(Cc4cccc(F)c4)s3)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc(C)c(C)s3)N=N2)cc1',
#  'COc1ccccc1N1C=C(CNc2nc3cc(Br)ccc3[nH]2)N=N1',
#  'CCc1cccc2sc(NC(C)C3=CN(Cc4ccccc4)N=N3)nc12',
#  'CC(C)c1cnc(NC(C)(C)C2=CN(CCN3CCCCC3)N=N2)s1',
#  'COc1ccc(N2C=C(CNc3nc4c(s3)-c3ccccc3CC4)N=N2)cc1',
#  'Cc1nc(NCC2=CN(c3ccc4ccccc4[n+]3C)N=N2)sc1Cl',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(F)cc(Br)cc4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(CNc3nc(Cc4ccccc4)c(C)[nH]3)N=N2)c1',
#  'CC(Nc1nc(-c2ccccc2)c[nH]1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc4ccc(Br)cc4s3)N=N2)cc1',
#  'Cc1nc(NCC2=CN(c3ccc4ccccc4[n+]3C)N=N2)sc1F',
#  'Cc1cc(-c2csc(NCC3=CN(Cc4ccccc4C)N=N3)n2)ccc1F',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(C(F)(F)F)c(Br)s2)N=N1',
#  'CC(Nc1nc2c(Br)cc(F)cc2s1)C1=CN(c2ccccc2)N=N1',
#  'CCc1nc(NCC2=CN(c3cccc(OC)c3)N=N2)sc1C',
#  'Cc1ccc(N2C=C(CSc3ncc[nH]3)N=N2)cc1',
#  'CC(C)(Nc1ncc(Cc2ccccc2)s1)C1=CN(c2ccccc2F)N=N1',
#  'Cc1sc(NC(C)C2=CN(c3ccc(F)cc3)N=N2)nc1-c1ccc(F)cc1',
#  'CC(Nc1nc2c(s1)CCCC2)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1coc(NCC2=CN(Cc3ccccc3)N=N2)n1',
#  'Fc1ccc(N2C=C(CSc3c[nH]c4ccccc34)N=N2)cc1',
#  'CC(C)(Nc1nc2cc(Cl)ccc2[nH]1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4c(s3)CCCCCC4)N=N2)c1',
#  'CC([18O][13c]1nc2cc(Cl)ccc2o1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'Cc1ccc(CN2C=C(CNc3nc(C(F)(F)F)c(Br)s3)N=N2)cc1',
#  'FC(F)(F)c1coc(NCC2=CN(CCN3CCCCC3)N=N2)n1',
#  'CC(C)(Nc1ncco1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)[18O][13c]3nc4cc(Cl)ccc4o3)N=N2)cc1',
#  'COc1ccc(N2C=C(CNc3nc4c(C)cc(C)cc4s3)N=N2)cc1',
#  'Fc1ccccc1CN1C=C(CSc2ncc[nH]2)N=N1',
#  'Fc1ccc(CN2C=C(CNc3nc4c(Cl)cc(F)cc4s3)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc4c(C)cc(Cl)cc4s3)N=N2)cc1',
#  'CC(Nc1nc2cc(Br)ccc2s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(Nc1nc2c(s1)CC(C(C)(C)C)CC2)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccc(N2C=C(C(C)Sc3nc4cc(F)ccc4o3)N=N2)cc1',
#  'Cc1ccc2[nH]c(SCC3=CN(c4ccccc4)N=N3)nc2c1',
#  'Fc1ccccc1CN1C=C(CNc2nc3cccc(Cl)c3[nH]2)N=N1',
#  'CC(Nc1nc2ccc(Br)cc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1cccc(N2C=C(C(C)Oc3nc4ccccc4s3)N=N2)c1',
#  'COc1ccccc1N1C=C(CNc2nc3c(F)ccc(F)c3s2)N=N1',
#  'CC(Sc1nc2c(F)cccc2s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(I)cccc4s3)N=N2)c1',
#  'CC(Nc1ncc(C(C)C)s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Fc1ccccc1CN1C=C(CNc2ncc(-c3ccc(Br)cc3)o2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3nccs3)N=N2)ccc2ccccc21',
#  'CCc1cnc(NC(C)C2=CN(Cc3ccc(C)cc3)N=N2)s1',
#  'Cc1cccc(N2C=C(C(C)Sc3nc4cccc(F)c4s3)N=N2)c1',
#  'Cc1cnc(NCC2=CN(Cc3ccc(F)cc3)N=N2)[nH]1',
#  'Cc1nc(NC(C)(C)C2=CN(Cc3ccccc3F)N=N2)sc1C',
#  'CCc1csc(NC(C)(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)n1',
#  'Cc1ccc(CN2C=C(C(C)(C)Oc3nc4c(F)cccc4s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc(Cc3ccccc3)c(C)[nH]2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(C3CC3)cs2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3ncc(Cc4ccc(F)c(F)c4)s3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4cc(C)ccc4[nH]3)N=N2)c1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc(-c4ccc(F)c(C)c4)cs3)N=N2)cc1',
#  'CC(Nc1ncc(-c2ccc(Cl)cc2)[nH]1)C1=CN(c2cccc(F)c2)N=N1',
#  'CC(Nc1nc(-c2ccccc2F)cs1)C1=CN(c2ccccc2F)N=N1',
#  'COc1ccc2[nH]c(SC(C)(C)C3=CN(CCN4CCCCC4)N=N3)nc2c1',
#  'Cc1ccc(N2C=C(CNc3ncc(Cc4ccc(F)c(F)c4)s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc3ccc(Cl)cc3s2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(Br)cc(F)cc4s3)N=N2)cc1',
#  'CCCn1c(NCC2=CN(c3cccc(C)c3)N=N2)nc2ccccc21',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1ccccc1CN1C=C(C(C)(C)Nc2nc(-c3ccc(F)c(F)c3)c(C)s2)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc(C4CC4)c(Br)s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(CNc2nc3c(C)cccc3s2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4c(s3)-c3ccccc3CC4)N=N2)c1',
#  'Fc1ccccc1N1C=C(CNc2nc3cc(Br)ccc3[nH]2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(-c3ccccc3C)cs2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Sc2nc3cc(Br)ccc3o2)N=N1',
#  'C[n+]1c(N2C=C(CSc3nc4cc(N)ccc4[nH]3)N=N2)ccc2ccccc21',
#  'Cc1cc(Cl)cc2sc(NC(C)C3=CN(Cc4ccccc4F)N=N3)nc12',
#  'CC(Nc1ncco1)C1=CN(CCN2CCCCC2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3ccccc3n2C)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(F)cc(F)cc4s3)N=N2)cc1',
#  'Fc1cccc(N2C=C(CNc3nc(-c4ccccc4F)cs3)N=N2)c1',
#  'Cc1cccc(CN2C=C(CNc3ncc(C)[nH]3)N=N2)c1',
#  'CC(Nc1nc2ccc(F)cc2o1)C1=CN(CCN2CCCCC2)N=N1',
#  'CC(C)(Nc1nccs1)C1=CN(c2ccccc2F)N=N1',
#  'Cc1ccccc1CN1C=C(C(C)Nc2nc3c(Br)cc(F)cc3s2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Oc3nc4c(F)cccc4s3)N=N2)cc1',
#  'CCc1csc(NC(C)C2=CN(c3ccccc3)N=N2)n1',
#  'CC(C)(Nc1nc2c(s1)CC(C(C)(C)C)CC2)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(Nc1nc2c(Br)cccc2s1)C1=CN(Cc2ccccc2F)N=N1',
#  'C1=C(CNc2nc3c(s2)CCCCC3)N=NN1CCN1CCCCC1',
#  'Cc1cc(C)c2nc(NCC3=CN(Cc4ccccc4C)N=N3)sc2c1',
#  'CCc1nc(NC(C)C2=CN(CCN3CCCCC3)N=N2)sc1C',
#  'CC(Nc1ncc(Cc2ccccc2)s1)C1=CN(c2ccccc2F)N=N1',
#  'Cc1ccccc1N1C=C(CNc2nc3cc(Cl)ccc3o2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)Nc2nc(-c3ccccc3)cs2)N=N1',
#  'Fc1cccc(N2C=C(CNc3nc4c(Cl)ccc(F)c4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(F)cccc4s3)N=N2)c1',
#  'CC(Nc1nc(C2CC2)c(Br)s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Fc1ccc(N2C=C(CNc3nc(-c4ccccc4)cs3)N=N2)cc1',
#  'Cc1ccc(N2C=C(C(C)Nc3nccn3C)N=N2)cc1',
#  'Cc1ccccc1N1C=C(CNc2ncc(CC(C)C)s2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(CCl)cs3)N=N2)cc1',
#  'O=C(O)c1sccc1OCC1=CN(c2cccc(F)c2)N=N1',
#  'CC(Sc1nc(-c2ccccc2)c[nH]1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1cnc(NC(C)C2=CN(Cc3ccccc3)N=N2)[nH]1',
#  'Fc1cccc(N2C=C(CNc3nc4ccc(C(F)(F)F)cc4s3)N=N2)c1',
#  'COc1cccc(N2C=C(CSc3nc4c(F)cccc4s3)N=N2)c1',
#  'COc1ccccc1N1C=C(CNc2nc3ccccc3n2C)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc(-c3ccc(F)c(F)c3)c(C)s2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3ccccc3n2Cc2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)(C)Sc3nc4cc(Br)ccc4o3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(Br)cccc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'COc1ccc(N2C=C(CSc3ccoc3C)N=N2)cc1',
#  'CCc1cccc2sc(NC(C)C3=CN(CCN4CCCCC4)N=N3)nc12',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(-c4ccccc4)c[nH]3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(C)c(C)s3)N=N2)c1',
#  'Cc1cc(C)c2nc(NCC3=CN(c4ccccc4F)N=N3)sc2c1',
#  'CC(C)(Nc1ncc(-c2ccc(Cl)cc2)[nH]1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cccc(N2C=C(CNc3ncc(Cc4ccccc4)s3)N=N2)c1',
#  'C[n+]1c(N2C=C(CNc3c[nH]c4ccccc34)N=N2)ccc2ccccc21',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4ccc(F)cc4o3)N=N2)cc1',
#  'CC1CCc2nc(NC(C)(C)C3=CN(c4ccccc4)N=N3)sc2C1',
#  'Fc1cccc2sc(OCC3=CN(CCN4CCCCC4)N=N3)nc12',
#  'CC(C)(Nc1cscc1N)C1=CN(CCN2CCCCC2)N=N1',
#  'CC(Nc1c[nH]c2ccccc12)C1=CN(c2ccccc2)N=N1',
#  'CCc1[nH]c(NC(C)(C)C2=CN(Cc3cccc(C)c3)N=N2)nc1-c1ccccc1',
#  'Fc1cccc(N2C=C(CNc3ncc(-c4ccc(Br)cc4)[nH]3)N=N2)c1',
#  'CC(Sc1nc2ccccc2o1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Sc3nc4ccccc4s3)N=N2)cc1',
#  'COc1cccc(N2C=C(CNc3nc4c(Cl)ccc(F)c4s3)N=N2)c1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3ncc(F)s3)N=N2)c1',
#  'CCn1c(NCC2=CN(c3ccc(C)cc3)N=N2)nc2ccccc21',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(C)co3)N=N2)c1',
#  'Cc1ccc(N2C=C(CNc3nc(-c4ccc(F)cc4F)cs3)N=N2)cc1',
#  'Fc1ccc(Cc2cnc(NCC3=CN(c4ccccc4F)N=N3)s2)c(F)c1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4ccccc4[nH]3)N=N2)cc1',
#  'CC(Nc1nc2c(Cl)cc(F)cc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)c1',
#  'Cc1nc(NC(C)C2=CN(c3ccccc3)N=N2)sc1Br',
#  'Cc1ccccc1N1C=C(C(C)Nc2nc(-c3ccc(F)cc3F)cs2)N=N1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc(C)c(Br)s3)N=N2)cc1',
#  'CC(=O)c1sccc1NC(C)(C)C1=CN(c2ccccc2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3ncc(-c4ccc(F)cc4)[nH]3)N=N2)c1',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3ncc(-c4ccc(F)cc4)o3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc(-c4ccc(F)c(F)c4)cs3)N=N2)c1',
#  'COc1ccc(N2C=C(CNc3ncc(Cl)s3)N=N2)cc1',
#  'Cc1cccc(N2C=C(CNc3nccn3C)N=N2)c1',
#  'Cc1cccc(CN2C=C(CNc3nc4c(F)ccc(F)c4s3)N=N2)c1',
#  'Brc1ccc2oc(SCC3=CN(c4ccccc4)N=N3)nc2c1',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc4c(F)cc(F)cc4s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)Nc2ncc(Cc3cccc(F)c3)s2)N=N1',
#  'CC(Nc1nc2ccc(F)cc2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1sc(NC(C)(C)C2=CN(Cc3ccccc3)N=N2)nc1C(C)C',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(C)cs3)N=N2)cc1',
#  'Cc1cccc(N2C=C(COc3nc4c(F)cccc4s3)N=N2)c1',
#  'CCc1csc(NC(C)C2=CN(Cc3cccc(C)c3)N=N2)n1',
#  'CCc1[nH]c(NC(C)C2=CN(c3ccccc3F)N=N2)nc1-c1ccccc1',
#  'Cc1ccccc1N1C=C(C(C)Sc2nc3ccccc3o2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Oc3cc(C(F)(F)F)sc3C(=O)O)N=N2)cc1',
#  'CC(C)(Nc1ncc(Cc2ccccc2)s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'COc1ccc(N2C=C(CNc3ncco3)N=N2)cc1',
#  'Fc1cccc(N2C=C(CNc3nc4cc(Cl)ccc4[nH]3)N=N2)c1',
#  'CC(Nc1nc2ccc(C(F)(F)F)cc2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CC(C)(Nc1nc2c(s1)CC(C(C)(C)C)CC2)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(C)(Oc1nc(-c2ccccc2)cs1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cnc(NC(C)(C)C2=CN(Cc3ccccc3C)N=N2)s1',
#  'FC(F)(F)c1ccc2nc(NCC3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'CC(Nc1ncc(-c2ccc(F)cc2)o1)C1=CN(Cc2ccccc2F)N=N1',
#  'CC(=O)c1sccc1NCC1=CN(c2ccc(C)cc2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc3c(C(F)(F)F)cccc3s2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4ccccc4s3)N=N2)c1',
#  'Fc1ccc(CN2C=C(CNc3ncc(F)s3)N=N2)cc1',
#  'CC(Nc1nc2c(Cl)cccc2s1)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3ncc[nH]3)N=N2)cc1',
#  'Cc1ccc(N2C=C(CNc3nc4cc(Cl)ccc4[nH]3)N=N2)cc1',
#  'Fc1cccc(N2C=C(CNc3nc4ccc(F)cc4o3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc3c(F)cccc3s2)N=N1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4cc(Br)ccc4s3)N=N2)c1',
#  'CC(Sc1nc2cc(Cl)ccc2o1)C1=CN(c2ccccc2F)N=N1',
#  'Cc1ccc(-c2cnc(NC(C)C3=CN(c4ccccc4)N=N3)[nH]2)cc1',
#  'CC(C)(Nc1cscc1N)C1=CN(c2cccc(F)c2)N=N1',
#  'COc1ccccc1N1C=C(C(C)Sc2c[nH]c3ccccc23)N=N1',
#  'CC(C)(Nc1nc(C2CC2)cs1)C1=CN(Cc2ccccc2)N=N1',
#  'CCc1ccc2nc(NC(C)C3=CN(c4ccccc4OC)N=N3)sc2c1',
#  'CC(Oc1ccsc1C(=O)O)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccc(CN2C=C(C(C)Sc3nc4ccccc4s3)N=N2)cc1',
#  'CC(Nc1nc2c(s1)CCCC2)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'CC(Nc1nc(-c2ccccc2F)cs1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(-c4ccccc4)cs3)N=N2)cc1',
#  'CC(Nc1nc(-c2c(F)cccc2F)cs1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cn1c(NC(C)(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)nc2ccccc21',
#  'Cc1ccc(N2C=C(C(C)Sc3ncc[nH]3)N=N2)cc1',
#  'Fc1ccccc1N1C=C(CNc2nc3c(C(F)(F)F)cccc3s2)N=N1',
#  'CC(C)(Nc1nc2c(Br)cc(F)cc2s1)C1=CN(c2ccccc2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3ncc(-c4ccc(Cl)cc4)[nH]3)N=N2)ccc2ccccc21',
#  'COc1cccc(N2C=C(C(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)Sc3nc4ccccc4n3C)N=N2)c1',
#  'CC(Nc1nc2c(s1)Cc1ccccc1-2)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Sc2nc3cccc(Cl)c3o2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc(-c4ccc(F)c(F)c4)cs3)N=N2)cc1',
#  'Cc1cccc(N2C=C(C(C)Oc3nc4ccccc4s3)N=N2)c1',
#  'Cc1sc(NC(C)C2=CN(c3ccccc3)N=N2)nc1-c1ccc(F)cc1',
#  'CCc1csc(NC(C)(C)C2=CN(c3ccc(C)cc3)N=N2)n1',
#  'COc1ccccc1N1C=C(CNc2ncc(-c3ccc(Cl)cc3)[nH]2)N=N1',
#  'Cc1nc(NC(C)(C)C2=CN(Cc3ccccc3F)N=N2)sc1Br',
#  'CC(Nc1ncc(C(C)C)s1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc(-c3ccc(F)cc3F)cs2)N=N1',
#  'COc1ccc(N2C=C(CNc3nc(-c4ccccc4)cs3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)Nc3ncc(Cc4ccccc4)s3)N=N2)c1',
#  'CC(Nc1cscc1N)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'COc1ccccc1N1C=C(C(C)Sc2nc3cc(F)ccc3o2)N=N1',
#  'Cc1csc(NCC2=CN(c3ccccc3F)N=N2)n1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc(C)c(C)o3)N=N2)cc1',
#  'CC(Sc1nc2cc(Br)ccc2o1)C1=CN(c2ccccc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nccs3)N=N2)c1',
#  'CC(Sc1nc2cc(Cl)ccc2[nH]1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Oc3cc(C(F)(F)F)sc3C(=O)O)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc3ccc(F)cc3o2)N=N1',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3ncc(F)s3)N=N2)ccc2ccccc21',
#  'COc1cccc(N2C=C(CNc3ncc(-c4ccc(Br)cc4)[nH]3)N=N2)c1',
#  'CC(C)(Nc1nc2ccccc2s1)C1=CN(c2ccccc2F)N=N1',
#  'CCc1cccc2sc(NC(C)(C)C3=CN(c4cccc(C)c4)N=N3)nc12',
#  'Cc1ccccc1CN1C=C(CNc2ncco2)N=N1',
#  'CCCc1nc(NC(C)C2=CN(Cc3ccccc3C)N=N2)sc1CC',
#  'CC(C)(Nc1cscc1N)C1=CN(c2ccccc2F)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Sc3nc4ccccc4s3)N=N2)c1',
#  'Cc1ccc(CN2C=C(COc3nc4c(F)cccc4s3)N=N2)cc1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nccn3C)N=N2)cc1',
#  'CC(C)(Nc1nc(C(F)(F)F)c(Br)s1)C1=CN(c2cccc(F)c2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nccs3)N=N2)cc1',
#  'CCCn1c(NC(C)C2=CN(Cc3ccccc3F)N=N2)nc2ccccc21',
#  'CCc1ccc2nc(NC(C)(C)C3=CN(c4cccc(F)c4)N=N3)sc2c1',
#  'CCc1nc(NCC2=CN(Cc3ccccc3C)N=N2)sc1C',
#  'Cc1nc(NCC2=CN(Cc3ccccc3F)N=N2)sc1C',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3c(s2)CCC3)N=N1',
#  'Cc1cccc2sc(NC(C)C3=CN(CCN4CCCCC4)N=N3)nc12',
#  'COc1ccc(N2C=C(C(C)(C)Nc3ncc(-c4ccc(Br)cc4)o3)N=N2)cc1',
#  'Cc1cccc(N2C=C(C(C)Nc3nc4c(F)cccc4s3)N=N2)c1',
#  'CC(Sc1c[nH]c2ccccc12)C1=CN(Cc2ccccc2)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3c(C)cc(C)cc3s2)N=N1',
#  'CCc1cnc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)s1',
#  'Fc1ccccc1N1C=C(CSc2c[nH]c3ccccc23)N=N1',
#  'CC(Nc1nc2ccc(Cl)cc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'Clc1cccc2nc(NCC3=CN(Cc4ccccc4)N=N3)[nH]c12',
#  'Cc1cccc(CN2C=C(CNc3nc(C4CC4)cs3)N=N2)c1',
#  'CC(C)(Nc1nc2ccc(Cl)cc2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc(-c4ccc(F)cc4)c(C)s3)N=N2)c1',
#  'CC(C)(Nc1nc2ccc(Br)cc2s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccccc1CN1C=C(CNc2ncc(-c3ccc(Br)cc3)o2)N=N1',
#  'CCCc1nc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)sc1CC',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3nc4c(I)cccc4s3)N=N2)c1',
#  'Cc1csc(NC(C)C2=CN(c3ccc4ccccc4[n+]3C)N=N2)n1',
#  'CCc1cccc2sc(NC(C)(C)C3=CN(c4ccc(F)cc4)N=N3)nc12',
#  'CC(Oc1cc(C(F)(F)F)sc1C(=O)O)C1=CN(c2ccc3ccccc3[n+]2C)N=N1',
#  'CC(C)(Nc1nc(CCl)cs1)C1=CN(c2cccc(F)c2)N=N1',
#  'C1=C(CNc2nc3ccccc3[nH]2)N=NN1CCN1CCCCC1',
#  'Cc1sc(NCC2=CN(c3ccccc3)N=N2)nc1-c1ccccc1',
#  'CC(C)(Nc1nc(-c2ccc(F)cc2F)cs1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'CC(C)(Nc1nc2ccccc2[nH]1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccc(CN2C=C(CNc3nc4cc(Br)ccc4[nH]3)N=N2)cc1',
#  'Fc1ccc2sc(NCC3=CN(c4ccccc4)N=N3)nc2c1',
#  'Fc1cnc(NCC2=CN(Cc3ccccc3)N=N2)s1',
#  'CC(Oc1nccs1)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)(C)Oc3nc4ccccc4s3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc(-c4ccc(C)cc4)cs3)N=N2)c1',
#  'Cc1ccc(-c2csc(NCC3=CN(c4ccc(C)cc4)N=N3)n2)cc1',
#  'COc1ccccc1N1C=C(C(C)(C)Sc2ccoc2C)N=N1',
#  'CC(Nc1nc2cc(Br)ccc2[nH]1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc4ccccc4[nH]3)N=N2)cc1',
#  'CC(C)(Nc1nc2c(F)cc(F)cc2s1)C1=CN(CCN2CCCCC2)N=N1',
#  'CCc1csc(NC(C)C2=CN(c3ccc(OC)cc3)N=N2)n1',
#  'Cc1ccc(CN2C=C(C(C)Oc3nc4c(F)cccc4s3)N=N2)cc1',
#  'CC(C)(Nc1cscc1N)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(C)(Sc1nc2cc(Cl)ccc2[nH]1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1ccc(N2C=C(CNc3nc4c(Cl)ccc(F)c4s3)N=N2)cc1',
#  'CC(Nc1ncc(F)s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc(CN2C=C(C(C)(C)Sc3nc(-c4ccccc4)c[nH]3)N=N2)cc1',
#  'CCc1cccc2sc(NC(C)C3=CN(c4ccccc4)N=N3)nc12',
#  'Cc1nc(NC(C)(C)C2=CN(c3ccccc3)N=N2)sc1Cl',
#  'Cc1occc1SC(C)(C)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2ncc(Br)s2)N=N1',
#  'CC(=O)c1sccc1NC(C)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'COc1cccc(N2C=C(C(C)Nc3nc(C(C)C)c(C)s3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc(-c3ccccc3C)cs2)N=N1',
#  'CC(C)(Sc1c[nH]c2ccccc12)C1=CN(CCN2CCCCC2)N=N1',
#  'Cc1cc(NC(C)(C)C2=CN(Cc3ccc(F)cc3)N=N2)c(C#N)s1',
#  'CC(C)Cn1c(NCC2=CN(c3ccccc3)N=N2)nc2ccccc21',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc(C(C)(C)C)c(Br)s3)N=N2)c1',
#  'CC(C)(Nc1nc(CCl)cs1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4cc(Cl)ccc4[nH]3)N=N2)c1',
#  'CC(C)c1cnc(NC(C)(C)C2=CN(Cc3ccccc3F)N=N2)s1',
#  'Cc1ccc2[nH]c(NC(C)C3=CN(Cc4ccccc4C)N=N3)nc2c1',
#  'CC(Nc1nc(C(F)(F)F)cs1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cc2nc(NC(C)(C)C3=CN(Cc4ccc(F)cc4)N=N3)sc2cc1C',
#  'CCn1c(NC(C)C2=CN(c3cccc(F)c3)N=N2)nc2ccccc21',
#  'CC(C)(Nc1nc2c(Br)cc(F)cc2s1)C1=CN(c2cccc(F)c2)N=N1',
#  'CCCc1nc(NCC2=CN(c3ccccc3C)N=N2)sc1CC',
#  'Fc1cccc(N2C=C(CSc3nc4c(F)cccc4s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)Nc3nc4ccccc4n3C)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)(C)Sc3ccoc3C)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)Nc3ncc(Br)s3)N=N2)c1',
#  'COc1cccc(N2C=C(C(C)(C)Sc3nc4ccccc4o3)N=N2)c1',
#  'Cc1ccc2nc(NC(C)(C)C3=CN(Cc4ccccc4)N=N3)sc2c1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc(C(F)(F)F)c(Br)s3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)Nc2nc3cc(F)ccc3s2)N=N1',
#  'Cc1ccc(CN2C=C(CNc3cc(C)sc3C#N)N=N2)cc1',
#  'CC(C)(Sc1nc2cc(Br)ccc2o1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4c(C(F)(F)F)cccc4s3)N=N2)c1',
#  'CC(C)(Sc1nc(-c2ccccc2)c[nH]1)C1=CN(c2ccccc2)N=N1',
#  'COc1ccccc1N1C=C(CNc2nc3cc(Cl)ccc3[nH]2)N=N1',
#  'Cc1cccc(N2C=C(CSc3nc4cc(Cl)ccc4[nH]3)N=N2)c1',
#  'CCc1nc(NC(C)(C)C2=CN(Cc3cccc(C)c3)N=N2)sc1C',
#  'CCc1nc(NC(C)C2=CN(c3ccc(C)cc3)N=N2)sc1C',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2ncc(Cc3cccc(F)c3)s2)N=N1',
#  'C[n+]1c(N2C=C(COc3csc(C(=O)O)c3)N=N2)ccc2ccccc21',
#  'C1=C(CNc2nc3ccccc3[nH]2)N=NN1Cc1ccccc1',
#  'COc1ccc(N2C=C(C(C)Nc3ncc(Br)s3)N=N2)cc1',
#  'CC(C)(Sc1nc(-c2ccccc2)c[nH]1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'COc1cccc(N2C=C(CNc3nc4ccccc4s3)N=N2)c1',
#  'CCn1c(SC(C)(C)C2=CN(c3ccccc3F)N=N2)nc2ccccc21',
#  'Cc1ccc(CN2C=C(C(C)(C)Nc3nc4c(s3)CCCCC4)N=N2)cc1',
#  'CC(Nc1nc2ccccc2n1C)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'COc1cccc(N2C=C(C(C)Sc3nc4cc(Br)ccc4o3)N=N2)c1',
#  'Fc1ccc(-c2cnc(NCC3=CN(c4ccc(F)cc4)N=N3)[nH]2)cc1',
#  'Cc1ccc(N2C=C(CNc3nc(C(F)(F)F)co3)N=N2)cc1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2nc(C3CC3)cs2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Oc3nccs3)N=N2)c1',
#  'Cc1nc(NC(C)C2=CN(c3ccccc3F)N=N2)sc1C',
#  'CC(Nc1nc2c(s1)CCCCCC2)C1=CN(CCN2CCCCC2)N=N1',
#  'COc1cccc(N2C=C(CNc3nc(-c4ccc(F)c(C)c4)cs3)N=N2)c1',
#  'COc1cccc(N2C=C(CNc3nc4c(s3)CCC4)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)(C)Nc2nc3cc(C)c(C)cc3s2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4cccc(Cl)c4[nH]3)N=N2)c1',
#  'Cc1cccc(N2C=C(CNc3nc(C(F)(F)F)co3)N=N2)c1',
#  'Cc1cc2nc(NCC3=CN(c4ccccc4C)N=N3)[nH]c2cc1C',
#  'C[n+]1c(N2C=C(C(C)(C)Nc3nc4c(s3)CCCC4)N=N2)ccc2ccccc21',
#  'CC(C)(Sc1nc2cc(Cl)ccc2o1)C1=CN(c2ccccc2F)N=N1',
#  'COc1ccccc1N1C=C(C(C)(C)Sc2nc3cccc(F)c3s2)N=N1',
#  'COc1ccc(N2C=C(C(C)Nc3nc(-c4ccc(F)c(C)c4)cs3)N=N2)cc1',
#  'CCc1csc(NC(C)C2=CN(c3ccccc3OC)N=N2)n1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(Br)cccc4s3)N=N2)cc1',
#  'Cc1ccc2[nH]c(NC(C)(C)C3=CN(c4ccccc4)N=N3)nc2c1',
#  'CC(C)(Sc1nc2cc(Cl)ccc2o1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc2nc(NC(C)C3=CN(Cc4ccccc4F)N=N3)sc2c1',
#  'CC(C)(Nc1nc(C2CC2)cs1)C1=CN(c2ccccc2F)N=N1',
#  'COc1ccccc1N1C=C(C(C)Nc2nc(C(F)(F)F)cs2)N=N1',
#  'CC(Nc1ncc(Cc2cc(F)cc(F)c2)s1)C1=CN(Cc2ccccc2F)N=N1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc4c(s3)CCCC4)N=N2)c1',
#  'Cc1cc(NCC2=CN(Cc3ccc(F)cc3)N=N2)c(C#N)s1',
#  'CC(C)(Nc1ncc(Cc2ccc(F)c(F)c2)s1)C1=CN(Cc2ccccc2)N=N1',
#  'CCCn1c(NC(C)C2=CN(c3cccc(F)c3)N=N2)nc2ccccc21',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc4ccccc4n3CC(C)C)N=N2)cc1',
#  'CC(Sc1nc2cccc(Cl)c2o1)C1=CN(Cc2ccccc2F)N=N1',
#  'CCCCn1c(NCC2=CN(c3ccccc3F)N=N2)nc2ccccc21',
#  'CC(C)(Nc1nc(-c2ccc(F)c(F)c2)cs1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'Cc1cccc(CN2C=C(CNc3ncc(Cc4ccc(F)c(F)c4)s3)N=N2)c1',
#  'Fc1ccc(N2C=C(CNc3nc4c(s3)CCCCC4)N=N2)cc1',
#  'COc1ccc(N2C=C(CNc3ncc(C(F)(F)F)s3)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3nc(-c4ccc(F)cc4)c(C)s3)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc4c(I)cccc4s3)N=N2)cc1',
#  'CC(Nc1nc2ccccc2o1)C1=CN(Cc2ccccc2)N=N1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)cc1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(C)cs3)N=N2)cc1',
#  'Cc1cc(C)c2nc(NCC3=CN(c4ccccc4C)N=N3)sc2c1',
#  'CC(Nc1nc(-c2ccccc2F)cs1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Fc1ccccc1CN1C=C(CNc2ncc(Cl)s2)N=N1',
#  'CCn1c(NC(C)(C)C2=CN(c3cccc(OC)c3)N=N2)nc2ccccc21',
#  'COc1cccc(N2C=C(C(C)(C)Sc3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'Cc1cc2nc(NCC3=CN(Cc4ccccc4C)N=N3)sc2cc1C',
#  'Cc1cccc(CN2C=C(C(C)(C)Nc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)c1',
#  'Cc1cnc(NC(C)C2=CN(c3ccccc3F)N=N2)s1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3cscc3N)N=N2)c1',
#  'COc1ccc(N2C=C(C(C)Nc3nc4c(s3)CC(C)CC4)N=N2)cc1',
#  'Cc1sc(NC(C)(C)C2=CN(c3ccc(F)cc3)N=N2)nc1C(C)C',
#  'COc1cccc(N2C=C(CNc3nc4cc(Cl)ccc4o3)N=N2)c1',
#  'Cc1cccc(CN2C=C(CNc3nc(C(C)C)c(C)s3)N=N2)c1',
#  'COc1ccccc1N1C=C(C(C)(C)Sc2nc3cc(Cl)ccc3[nH]2)N=N1',
#  'Cc1cccc(N2C=C(C(C)Sc3nc4ccccc4o3)N=N2)c1',
#  'Cc1cccc(CN2C=C(C(C)Nc3ncc(C(C)C)s3)N=N2)c1',
#  'Cc1cccc(N2C=C(CNc3nc4c(C)cc(Cl)cc4s3)N=N2)c1',
#  'Cc1ccccc1CN1C=C(CNc2nc3ccc(C(F)(F)F)cc3s2)N=N1',
#  'CCOc1ccc2[nH]c(SC(C)(C)C3=CN(c4ccccc4F)N=N3)nc2c1',
#  'Cc1ccc(-c2csc(NC(C)C3=CN(c4ccccc4)N=N3)n2)cc1',
#  'CC(C)(Sc1nc2cccc(F)c2s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'CC(C)(Nc1c[nH]c2ccccc12)C1=CN(c2ccccc2)N=N1',
#  'CC(Nc1nc2c(I)cccc2s1)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1ccccc1N1C=C(C(C)(C)Nc2ncc(F)s2)N=N1',
#  'CC(Nc1nc2ccccc2n1C)C1=CN(c2ccc(F)cc2)N=N1',
#  'Cc1nc(NC(C)C2=CN(c3ccc(F)cc3)N=N2)sc1C',
#  'CC(Sc1nc2c(F)cccc2s1)C1=CN(Cc2ccc(F)cc2)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4ccccc4n3C(C)C)N=N2)c1',
#  'Cc1nc(NC(C)(C)C2=CN(Cc3ccccc3F)N=N2)oc1C',
#  'Cc1csc(NC(C)C2=CN(Cc3ccc(F)cc3)N=N2)n1',
#  'Cc1cc2nc(NC(C)C3=CN(Cc4ccccc4)N=N3)[nH]c2cc1C',
#  'CC(Nc1ncc(Cl)s1)C1=CN(c2ccccc2F)N=N1',
#  'CC(C)(Nc1nc2ccc(C(F)(F)F)cc2s1)C1=CN(Cc2ccccc2)N=N1',
#  'Cc1ccc(N2C=C(C(C)(C)Nc3nc(C)c(C)s3)N=N2)cc1',
#  'COc1ccc(N2C=C(C(C)(C)Nc3nc4c(s3)Cc3ccccc3-4)N=N2)cc1',
#  'CC(Nc1nc(CCl)cs1)C1=CN(Cc2ccccc2F)N=N1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3nc4cc(Cl)ccc4[nH]3)N=N2)c1',
#  'Cc1cc(Cl)cc2sc(NCC3=CN(c4cccc(F)c4)N=N3)nc12',
#  'Cc1ccc(CN2C=C(C(C)Nc3nc4c(s3)CCc3ccccc3-4)N=N2)cc1',
#  'Cc1cccc(CN2C=C(C(C)Nc3nc4c(C)cc(Cl)cc4s3)N=N2)c1',
#  'CC(C)Cc1cnc(NC(C)C2=CN(c3ccccc3)N=N2)s1',
#  'Cc1ccc(N2C=C(C(C)Nc3nc4ccc(Br)cc4s3)N=N2)cc1',
#  'COc1cccc(N2C=C(C(C)(C)Nc3ncc(Br)s3)N=N2)c1',
#  'CCn1c(NC(C)C2=CN(c3cccc(C)c3)N=N2)nc2ccccc21',
#  'Cc1cccc(N2C=C(CNc3nc(-c4ccc(F)c(F)c4)c(C)s3)N=N2)c1',
#  'Cc1cccc(N2C=C(CNc3nc(-c4ccccc4C)cs3)N=N2)c1',
#  'COc1cccc(N2C=C(CSc3ccoc3C)N=N2)c1',
#  'Cc1cccc(N2C=C(C(C)(C)Nc3ncc(-c4ccc(F)cc4)o3)N=N2)c1',
#  'CC(Nc1nc2c(F)cc(F)cc2s1)C1=CN(c2ccccc2)N=N1',
#  'Cc1ccccc1CN1C=C(CNc2ncc(Cc3ccccc3)s2)N=N1',
#  'Cc1occc1SC(C)C1=CN(Cc2ccccc2F)N=N1',
#  ...]

# %% [markdown]
# f) Exportar los resultados en un archivo con formato csv.

# %%
#Export results as .CSV File
df = pd.DataFrame(smis2, columns=["colummn"])
df.to_csv('bis_heterocycles.csv', index=False)
df
# Out:
#                                                 colummn
# 0          CC(Nc1nc2cc(Br)ccc2s1)C1=CN(c2cccc(F)c2)N=N1
# 1     COc1ccc(N2C=C(CNc3ncc(Cc4cc(F)cc(F)c4)s3)N=N2)cc1
# 2     Cc1ccccc1N1C=C(C(C)Nc2ncc(Cc3ccc(F)c(F)c3)s2)N=N1
# 3                 Cc1ccccc1CN1C=C(C(C)(C)Sc2ccoc2C)N=N1
# 4      COc1ccccc1N1C=C(C(C)(C)Nc2nc3ccccc3n2CC(C)C)N=N1
# ...                                                 ...
# 7879    Fc1ccc(-c2cnc(NCC3=CN(Cc4ccccc4F)N=N3)[nH]2)cc1
# 7880              Fc1ccc(CN2C=C(CNc3nc(CCl)cs3)N=N2)cc1
# 7881         Cn1c(-c2ccccc2)cnc1NCC1=CN(CCN2CCCCC2)N=N1
# 7882      Cc1cc2nc(NC(C)(C)C3=CN(c4ccccc4F)N=N3)sc2cc1C
# 7883                  Cc1ccc(CN2C=C(CSc3ccoc3C)N=N2)cc1
#
# [7884 rows x 1 columns]

# %% [markdown]
# e) Visualizar los compuestos  generados.

# %%
PandasTools.AddMoleculeColumnToFrame(df,'colummn','Molecule',includeFingerprints=True)
print([str(x) for x in  df.columns])

PandasTools.FrameToGridImage(df,column= 'Molecule', molsPerRow=5,subImgSize=(350,350))
# Out:
# ['colummn', 'Molecule']
# /usr/local/lib/python3.11/dist-packages/rdkit/Chem/Draw/IPythonConsole.py:343: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   warnings.warn(

# %%
rxn_1 = AllChem.ReactionFromSmarts('[#7;A;X3;H2,H1;!$(NC=[O,N,S]):3][c:2]:[c:1][*;A;Br,I;$(*c1ccccc1)].[#6;A;$(C-[#6]):5]#[#6;A;$(C-[#6]):4]>>[#7:3]-1-[c:2][c:1]-[#6:5]=[#6:4]-1')
rxn_1

# %% [markdown]
# # Para saber más:
# * Chevillard F, Kolb P (2015) [SCUBIDOO: A Large yet Screenable and Easily Searchable Database of Computationally Created Chemical Compounds Optimized toward High Likelihood of Synthetic Tractability.](https://pubs.acs.org/doi/10.1021/acs.jcim.5b00203) *J Chem Inf Model*. 55:1824-35.
# * Dorschner KV, Toomey D, Brennan MP, Heinemann T, Duffy FJ, Nolan KB, Cox D, Adamo MF, Chubb AJ (2011) [TIN-a combinatorial compound collection of synthetically feasible multicomponent synthesis products.](https://pubs.acs.org/doi/10.1021/ci100443x) *J Chem Inf Model*. 51:986-95.
# * Humbeck L, Weigang S, Schäfer T, Mutzel P, Koch O (2018) [CHIPMUNK: A virtual synthesizable small-molecule library for medicinal chemistry, exploitable for protein-protein interaction modulators.](https://chemistry-europe.onlinelibrary.wiley.com/doi/10.1002/cmdc.201700689) *ChemMedChem*. 13:532–539.
# * Lessel U, Wellenzohn B, Lilienthal M, Claussen H (2009) [Searching fragment spaces with feature trees.](https://pubs.acs.org/doi/10.1021/ci800272a) *J Chem Inf Model.* 49:270–279.
# * Massarotti A, Brunco A, Sorba G, Tron GC (2014) [ZINClick: a database of 16 million novel, patentable, and readily synthesizable 1,4-disubstituted triazoles.](https://pubs.acs.org/doi/10.1021/ci400529h) *J Chem Inf Model.* 54:396-406. doi: 10.1021/ci400529h. Epub 2014 Jan 31. PMID: 24451008.
# * Saldívar-González FI, Huerta-García CS. & Medina-Franco JL. (2020) [Chemoinformatics-based enumeration of chemical libraries: a tutorial.](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-020-00466-z) *J Cheminform.* 12, 64.
# * Shafi S, Alam MM, Mulakayala N, Mulakayala C, Vanaja G, Kalle AM et al (2012) [Synthesis of novel 2-mercapto benzothiazole and 1,2,3-triazole based bis-heterocycles: their anti-inflammatory and anti-nociceptive activities.](https://www.sciencedirect.com/science/article/abs/pii/S0223523412000475?via%3Dihub) *Eur J Med Chem.* 49:324–333.
# * Schmidt, R.; Ehmki, E. S. R.; Ohm, F.; Ehrlich, H.-C.; Mashychev, A.; Rarey, M. (2019) [Comparing Molecular Patterns using the Example of SMARTS: Theory and Algorithms](https://pubs.acs.org/doi/10.1021/acs.jcim.9b00249). *J Chem Inf Model.* 59(6):2560-2571.
